# %%
import pandas as pd
import os
from pathlib import Path
from typing import Union, List
import glob

def load_all_crypto_data(
    base_path: Union[str, Path],
    symbols: List[str] = None,
    freq: str = "1d",
    format_type: str = "wide"  # New parameter: "wide" or "long"
) -> pd.DataFrame:
    """
    Load and merge data for multiple cryptocurrencies across all available dates
    
    Args:
        base_path (str/Path): Base path for data files
        symbols (List[str]): List of trading pairs (e.g., ["BTCUSDT", "ETHUSDT"])
                          If None, will load all available symbols
        freq (str): Frequency, e.g., "1m" or "1d"
        format_type (str): Output format - "wide" (default) or "long"
    
    Returns:
        pd.DataFrame: DataFrame with all cryptocurrencies data
    """
    # Ensure base_path is a Path object
    base_path = Path(base_path)
    
    # If symbols not provided, discover all available symbols
    if symbols is None:
        # Look for subfolders that might be cryptocurrency names
        symbols = []
        for item in base_path.iterdir():
            if item.is_dir() and item.name.endswith("USDT"):
                # Check if the frequency subfolder exists
                freq_folder = item / freq
                if freq_folder.exists() and freq_folder.is_dir():
                    symbols.append(item.name)
        
        symbols.sort()
        print(f"Found {len(symbols)} available symbols with {freq} frequency: {symbols[:5]}...")
    
    # Dictionary to store DataFrames for each symbol
    symbol_dfs = {}
    
    # Load data for each symbol
    for i, symbol in enumerate(symbols):
        try:
            print(f"Processing {i+1}/{len(symbols)}: {symbol}")
            
            # Get path to the frequency folder for this symbol
            symbol_freq_path = base_path / symbol / freq
            
            if not symbol_freq_path.exists():
                print(f"  No {freq} folder found for {symbol}")
                continue
                
            # Get all csv files in the frequency folder
            csv_files = sorted(list(symbol_freq_path.glob("*.csv")))
            
            if not csv_files:
                print(f"  No CSV files found for {symbol} in {freq} folder")
                continue
                
            # Read and merge all CSV files for this symbol
            dfs = []
            for file in csv_files:
                try:
                    df = pd.read_csv(file)
                    dfs.append(df)
                except Exception as e:
                    print(f"  Error reading file {file.name}: {e}")
            
            if not dfs:
                print(f"  No data successfully loaded for {symbol}")
                continue
                
            # Combine all data for this symbol
            symbol_df = pd.concat(dfs, ignore_index=True)
            
            # Format time columns
            symbol_df['open_time'] = pd.to_datetime(symbol_df['open_time'])
            
            # Remove duplicates
            symbol_df = symbol_df.drop_duplicates(subset=['open_time'], keep='first')
            
            # Sort by time
            symbol_df = symbol_df.sort_values('open_time').reset_index(drop=True)
            
            # Keep only essential columns
            try:
                columns_to_keep = ['open_time', 'open', 'high', 'low', 'close', 'volume', 
                                   'quote_asset_volume', 'number_of_trades', 
                                   'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume']
                symbol_df = symbol_df[columns_to_keep]
            except KeyError as e:
                print(f"  Warning: Some columns are missing in {symbol} data - {e}")
                # Fallback to only columns that exist
                available_columns = ['open_time']
                for col in ['open', 'high', 'low', 'close', 'volume', 'quote_asset_volume', 
                           'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume']:
                    if col in symbol_df.columns:
                        available_columns.append(col)
                symbol_df = symbol_df[available_columns]
            
            # For long format, we'll add the symbol column here
            if format_type.lower() == "long":
                symbol_df['symbol'] = symbol
                symbol_dfs[symbol] = symbol_df
            else:
                # For wide format, rename columns to include symbol
                rename_dict = {
                    'open': f'{symbol}_open',
                    'high': f'{symbol}_high',
                    'low': f'{symbol}_low',
                    'close': f'{symbol}_close',
                    'volume': f'{symbol}_volume'
                }
                
                # Only rename columns that exist
                rename_dict = {k: v for k, v in rename_dict.items() if k in symbol_df.columns}
                
                # Add additional columns if they exist
                additional_cols = {
                    'quote_asset_volume': f'{symbol}_quote_volume',
                    'number_of_trades': f'{symbol}_num_of_trades',
                    'taker_buy_base_asset_volume': f'{symbol}_taker_buy_base_vol',
                    'taker_buy_quote_asset_volume': f'{symbol}_taker_buy_quote_vol'
                }
                
                for col, new_name in additional_cols.items():
                    if col in symbol_df.columns:
                        rename_dict[col] = new_name
                
                symbol_df = symbol_df.rename(columns=rename_dict)
                symbol_dfs[symbol] = symbol_df
            
            print(f"  Successfully loaded {symbol} with {len(symbol_df)} rows")
        except Exception as e:
            print(f"  Error processing {symbol}: {e}")
    
    if not symbol_dfs:
        print(f"Warning: No data was successfully loaded for any symbol with frequency {freq}.")
        return pd.DataFrame()  # Return empty DataFrame instead of raising error
    
    # Handle long format
    if format_type.lower() == "long":
        print("\nCombining all symbols into long format...")
        
        # Concatenate all DataFrames (already in long format)
        result_df = pd.concat(list(symbol_dfs.values()), ignore_index=True)
        
        # Sort by symbol and time
        result_df = result_df.sort_values(['symbol', 'open_time']).reset_index(drop=True)
        
        print(f"Final long-format dataset has {len(result_df)} rows with data for {len(symbol_dfs)} symbols")
        
        return result_df
    
    # Handle wide format (original behavior)
    print("\nMerging data from all symbols into wide format...")
    # Start with the first DataFrame (preferably choose one with the most complete data)
    # Finding the symbol with the most data points
    symbol_counts = {symbol: len(df) for symbol, df in symbol_dfs.items()}
    first_symbol = max(symbol_counts, key=symbol_counts.get)
    print(f"Using {first_symbol} as the base for merging (has {symbol_counts[first_symbol]} data points)")
    
    result_df = symbol_dfs[first_symbol].copy()
    
    # Merge with other DataFrames on open_time
    for symbol, df in symbol_dfs.items():
        if symbol == first_symbol:
            continue
        
        print(f"  Merging {symbol} ({len(df)} rows)")
        result_df = pd.merge(result_df, df, on='open_time', how='outer')
    
    # Sort by time
    result_df = result_df.sort_values('open_time').reset_index(drop=True)
    
    # Set open_time as index for easier time-series analysis
    result_df.set_index('open_time', inplace=True)
    
    print(f"Final wide-format dataset has {len(result_df)} rows with {len(result_df.columns)} columns")
    
    return result_df

def convert_wide_to_long(df, id_vars=None):
    """
    Convert a wide format DataFrame to long format
    
    Args:
        df: Wide format DataFrame
        id_vars: Columns to use as identifiers (if None, uses index)
    
    Returns:
        pd.DataFrame: Long format DataFrame
    """
    if df.empty:
        return df
    
    # If no id_vars specified, use the index
    if id_vars is None:
        # Reset index to make it a column
        df = df.reset_index()
        id_vars = ['open_time']
    
    # Create a list of column tuples (symbol, metric)
    value_vars = []
    for col in df.columns:
        if col not in id_vars and '_' in col:
            value_vars.append(col)
    
    # Melt the DataFrame
    long_df = pd.melt(df, id_vars=id_vars, value_vars=value_vars, 
                      var_name='temp', value_name='value')
    
    # Split the temp column into symbol and metric
    long_df[['symbol', 'metric']] = long_df['temp'].str.split('_', n=1, expand=True)
    
    # Drop the temp column
    long_df = long_df.drop('temp', axis=1)
    
    # Pivot to get metrics as columns
    long_df = long_df.pivot_table(index=['open_time', 'symbol'], 
                                 columns='metric', 
                                 values='value').reset_index()
    
    # Flatten the column names
    long_df.columns.name = None
    
    return long_df

def check_data_quality(df, format_type="wide"):
    """
    Check quality of the cryptocurrency DataFrame
    
    Args:
        df: DataFrame to check
        format_type: "wide" or "long"
    
    Returns:
        dict: Dictionary with various data quality metrics
    """
    if df.empty:
        return {
            'total_rows': 0,
            'date_range': (None, None),
            'symbols_count': 0,
            'symbols': [],
            'completeness': {}
        }
    
    quality_report = {
        'total_rows': len(df)
    }
    
    if format_type.lower() == "long":
        # For long format
        quality_report['date_range'] = (df['open_time'].min(), df['open_time'].max())
        symbols = df['symbol'].unique().tolist()
        quality_report['symbols_count'] = len(symbols)
        quality_report['symbols'] = symbols
        
        # Check completeness by symbol
        quality_report['completeness'] = {}
        for symbol in symbols:
            symbol_data = df[df['symbol'] == symbol]
            metrics = ['open', 'high', 'low', 'close', 'volume']
            completeness = {}
            
            for metric in metrics:
                if metric in df.columns:
                    pct_non_null = (100 - (symbol_data[metric].isnull().sum() / len(symbol_data) * 100))
                    completeness[metric] = f"{pct_non_null:.2f}%"
            
            quality_report['completeness'][symbol] = completeness
    else:
        # For wide format
        quality_report['date_range'] = (df.index.min(), df.index.max())
        
        # Get all symbols from column names
        symbols = list(set([col.split('_')[0] for col in df.columns if '_' in col]))
        quality_report['symbols_count'] = len(symbols)
        quality_report['symbols'] = symbols
        
        # Check completeness by symbol
        quality_report['completeness'] = {}
        for symbol in symbols:
            symbol_cols = [col for col in df.columns if col.startswith(f'{symbol}_')]
            completeness = 100 - (df[symbol_cols].isnull().any(axis=1).sum() / len(df) * 100)
            quality_report['completeness'][symbol] = f"{completeness:.2f}%"
    
    return quality_report

def save_crypto_data(df, output_path, format="parquet"):
    """
    Save cryptocurrency DataFrame to disk
    
    Args:
        df: DataFrame to save
        output_path: Path to save the file
        format: Format to save ('parquet' or 'csv')
    """
    if df.empty:
        print("Warning: DataFrame is empty, not saving to disk.")
        return
    
    output_path = Path(output_path)
    os.makedirs(output_path.parent, exist_ok=True)
    
    if format.lower() == "parquet":
        df.to_parquet(output_path)
        print(f"Saved data to {output_path}")
    elif format.lower() == "csv":
        df.to_csv(output_path)
        print(f"Saved data to {output_path}")
    else:
        raise ValueError(f"Unsupported format: {format}")

# %% [markdown]
# load parquet

# %%
def load_parquet_data(file_path):
    """
    Load cryptocurrency data from a parquet file
    
    Args:
        file_path: Path to the parquet file
        
    Returns:
        pd.DataFrame: DataFrame with cryptocurrency data
    """
    try:
        df = pd.read_parquet(file_path)
        print(f"Successfully loaded data from {file_path}")
        print(f"Shape: {df.shape} (rows, columns)")
        
        if 'symbol' in df.columns:
            # Long format
            print(f"Format: Long format")
            print(f"Date range: {df['open_time'].min()} to {df['open_time'].max()}")
            symbols = df['symbol'].unique()
            print(f"Contains data for {len(symbols)} cryptocurrencies")
        else:
            # Wide format
            print(f"Format: Wide format")
            print(f"Date range: {df.index.min()} to {df.index.max()}")
            symbols = list(set([col.split('_')[0] for col in df.columns if '_' in col]))
            print(f"Contains data for {len(symbols)} cryptocurrencies")
        
        return df
    except Exception as e:
        print(f"Error loading parquet file: {e}")
        return None

def explore_directory_structure(base_path, max_depth=3):
    """
    Explore the directory structure to understand how files are organized
    
    Args:
        base_path: Base path to explore
        max_depth: Maximum depth to explore
    """
    base_path = Path(base_path)
    
    def _explore(path, depth, prefix=""):
        if depth > max_depth:
            return
        
        items = list(path.iterdir())
        items.sort()
        
        for i, item in enumerate(items):
            is_last = i == len(items) - 1
            connector = "└── " if is_last else "├── "
            
            print(f"{prefix}{connector}{item.name}")
            
            if item.is_dir() and depth < max_depth:
                next_prefix = prefix + ("    " if is_last else "│   ")
                _explore(item, depth + 1, next_prefix)
    
    print(f"Directory structure of {base_path}:")
    _explore(base_path, 1)

# Example usage
if __name__ == "__main__":
    base_path = "/Users/mouyasushi/Desktop/quantDevops/Research/Alpha-Research/kline/binance"
    
    # Explore directory structure to understand how files are organized
    explore_directory_structure(base_path)
    
    # Set frequency
    freq = "1d"  # Options might be "1d", "1m", etc.
    
    # Load all available symbols with the specified frequency in LONG format
    print("\n=== Loading data in LONG format ===")
    all_crypto_df_long = load_all_crypto_data(
        base_path=base_path,
        symbols=None,  # Load all available symbols
        freq=freq,
        format_type="long"  # Specify long format
    )
    
    # Check data quality
    if not all_crypto_df_long.empty:
        quality_report = check_data_quality(all_crypto_df_long, format_type="long")
        print("\nData Quality Report:")
        print(f"Total rows: {quality_report['total_rows']}")
        print(f"Date range: {quality_report['date_range'][0]} to {quality_report['date_range'][1]}")
        print(f"Total symbols: {quality_report['symbols_count']}")
        
        # Save the long format data
        output_file_long = Path(base_path) / f"all_crypto_data_{freq}_long.parquet"
        save_crypto_data(all_crypto_df_long, output_file_long, format="parquet")
        
        # Example: Show some sample data
        print("\nSample of long-format data:")
        print(all_crypto_df_long.head())
    else:
        print(f"No data was loaded. Check file path and frequency.")
# Out:
# Directory structure of /Users/mouyasushi/Desktop/quantDevops/Research/Alpha-Research/kline/binance:
# ├── AAVEUSDT
# │   └── 1d
# │       ├── AAVEUSDT_2021-01-01_1d.csv
# │       ├── AAVEUSDT_2021-01-02_1d.csv
# │       ├── AAVEUSDT_2021-01-03_1d.csv
# │       ├── AAVEUSDT_2021-01-04_1d.csv
# │       ├── AAVEUSDT_2021-01-05_1d.csv
# │       ├── AAVEUSDT_2021-01-06_1d.csv
# │       ├── AAVEUSDT_2021-01-07_1d.csv
# │       ├── AAVEUSDT_2021-01-08_1d.csv
# │       ├── AAVEUSDT_2021-01-09_1d.csv
# │       ├── AAVEUSDT_2021-01-10_1d.csv
# │       ├── AAVEUSDT_2021-01-11_1d.csv
# │       ├── AAVEUSDT_2021-01-12_1d.csv
# │       ├── AAVEUSDT_2021-01-13_1d.csv
# │       ├── AAVEUSDT_2021-01-14_1d.csv
# │       ├── AAVEUSDT_2021-01-15_1d.csv
# │       ├── AAVEUSDT_2021-01-16_1d.csv
# │       ├── AAVEUSDT_2021-01-17_1d.csv
# │       ├── AAVEUSDT_2021-01-18_1d.csv
# │       ├── AAVEUSDT_2021-01-19_1d.csv
# │       ├── AAVEUSDT_2021-01-20_1d.csv
# │       ├── AAVEUSDT_2021-01-21_1d.csv
# │       ├── AAVEUSDT_2021-01-22_1d.csv
# │       ├── AAVEUSDT_2021-01-23_1d.csv
# │       ├── AAVEUSDT_2021-01-24_1d.csv
# │       ├── AAVEUSDT_2021-01-25_1d.csv
# │       ├── AAVEUSDT_2021-01-26_1d.csv
# │       ├── AAVEUSDT_2021-01-27_1d.csv
# │       ├── AAVEUSDT_2021-01-28_1d.csv
# │       ├── AAVEUSDT_2021-01-29_1d.csv
# │       ├── AAVEUSDT_2021-01-30_1d.csv
# │       ├── AAVEUSDT_2021-01-31_1d.csv
# │       ├── AAVEUSDT_2021-02-01_1d.csv
# │       ├── AAVEUSDT_2021-02-02_1d.csv
# │       ├── AAVEUSDT_2021-02-03_1d.csv
# │       ├── AAVEUSDT_2021-02-04_1d.csv
# │       ├── AAVEUSDT_2021-02-05_1d.csv
# │       ├── AAVEUSDT_2021-02-06_1d.csv
# │       ├── AAVEUSDT_2021-02-07_1d.csv
# │       ├── AAVEUSDT_2021-02-08_1d.csv
# │       ├── AAVEUSDT_2021-02-09_1d.csv
# │       ├── AAVEUSDT_2021-02-10_1d.csv
# │       ├── AAVEUSDT_2021-02-11_1d.csv
# │       ├── AAVEUSDT_2021-02-12_1d.csv
# │       ├── AAVEUSDT_2021-02-13_1d.csv
# │       ├── AAVEUSDT_2021-02-14_1d.csv
# │       ├── AAVEUSDT_2021-02-15_1d.csv
# │       ├── AAVEUSDT_2021-02-16_1d.csv
# │       ├── AAVEUSDT_2021-02-17_1d.csv
# │       ├── AAVEUSDT_2021-02-18_1d.csv
# │       ├── AAVEUSDT_2021-02-19_1d.csv
# │       ├── AAVEUSDT_2021-02-20_1d.csv
# │       ├── AAVEUSDT_2021-02-21_1d.csv
# │       ├── AAVEUSDT_2021-02-22_1d.csv
# │       ├── AAVEUSDT_2021-02-23_1d.csv
# │       ├── AAVEUSDT_2021-02-24_1d.csv
# │       ├── AAVEUSDT_2021-02-25_1d.csv
# │       ├── AAVEUSDT_2021-02-26_1d.csv
# │       ├── AAVEUSDT_2021-02-27_1d.csv
# │       ├── AAVEUSDT_2021-02-28_1d.csv
# │       ├── AAVEUSDT_2021-03-01_1d.csv
# │       ├── AAVEUSDT_2021-03-02_1d.csv
# │       ├── AAVEUSDT_2021-03-03_1d.csv
# │       ├── AAVEUSDT_2021-03-04_1d.csv
# │       ├── AAVEUSDT_2021-03-05_1d.csv
# │       ├── AAVEUSDT_2021-03-06_1d.csv
# │       ├── AAVEUSDT_2021-03-07_1d.csv
# │       ├── AAVEUSDT_2021-03-08_1d.csv
# │       ├── AAVEUSDT_2021-03-09_1d.csv
# │       ├── AAVEUSDT_2021-03-10_1d.csv
# │       ├── AAVEUSDT_2021-03-11_1d.csv
# │       ├── AAVEUSDT_2021-03-12_1d.csv
# │       ├── AAVEUSDT_2021-03-13_1d.csv
# │       ├── AAVEUSDT_2021-03-14_1d.csv
# │       ├── AAVEUSDT_2021-03-15_1d.csv
# │       ├── AAVEUSDT_2021-03-16_1d.csv
# │       ├── AAVEUSDT_2021-03-17_1d.csv
# │       ├── AAVEUSDT_2021-03-18_1d.csv
# │       ├── AAVEUSDT_2021-03-19_1d.csv
# │       ├── AAVEUSDT_2021-03-20_1d.csv
# │       ├── AAVEUSDT_2021-03-21_1d.csv
# │       ├── AAVEUSDT_2021-03-22_1d.csv
# │       ├── AAVEUSDT_2021-03-23_1d.csv
# │       ├── AAVEUSDT_2021-03-24_1d.csv
# │       ├── AAVEUSDT_2021-03-25_1d.csv
# │       ├── AAVEUSDT_2021-03-26_1d.csv
# │       ├── AAVEUSDT_2021-03-27_1d.csv
# │       ├── AAVEUSDT_2021-03-28_1d.csv
# │       ├── AAVEUSDT_2021-03-29_1d.csv
# │       ├── AAVEUSDT_2021-03-30_1d.csv
# │       ├── AAVEUSDT_2021-03-31_1d.csv
# │       ├── AAVEUSDT_2021-04-01_1d.csv
# │       ├── AAVEUSDT_2021-04-02_1d.csv
# │       ├── AAVEUSDT_2021-04-03_1d.csv
# │       ├── AAVEUSDT_2021-04-04_1d.csv
# │       ├── AAVEUSDT_2021-04-05_1d.csv
# │       ├── AAVEUSDT_2021-04-06_1d.csv
# │       ├── AAVEUSDT_2021-04-07_1d.csv
# │       ├── AAVEUSDT_2021-04-08_1d.csv
# │       ├── AAVEUSDT_2021-04-09_1d.csv
# │       ├── AAVEUSDT_2021-04-10_1d.csv
# │       ├── AAVEUSDT_2021-04-11_1d.csv
# │       ├── AAVEUSDT_2021-04-12_1d.csv
# │       ├── AAVEUSDT_2021-04-13_1d.csv
# │       ├── AAVEUSDT_2021-04-14_1d.csv
# │       ├── AAVEUSDT_2021-04-15_1d.csv
# │       ├── AAVEUSDT_2021-04-16_1d.csv
# │       ├── AAVEUSDT_2021-04-17_1d.csv
# │       ├── AAVEUSDT_2021-04-18_1d.csv
# │       ├── AAVEUSDT_2021-04-19_1d.csv
# │       ├── AAVEUSDT_2021-04-20_1d.csv
# │       ├── AAVEUSDT_2021-04-21_1d.csv
# │       ├── AAVEUSDT_2021-04-22_1d.csv
# │       ├── AAVEUSDT_2021-04-23_1d.csv
# │       ├── AAVEUSDT_2021-04-24_1d.csv
# │       ├── AAVEUSDT_2021-04-25_1d.csv
# │       ├── AAVEUSDT_2021-04-26_1d.csv
# │       ├── AAVEUSDT_2021-04-27_1d.csv
# │       ├── AAVEUSDT_2021-04-28_1d.csv
# │       ├── AAVEUSDT_2021-04-29_1d.csv
# │       ├── AAVEUSDT_2021-04-30_1d.csv
# │       ├── AAVEUSDT_2021-05-01_1d.csv
# │       ├── AAVEUSDT_2021-05-02_1d.csv
# │       ├── AAVEUSDT_2021-05-03_1d.csv
# │       ├── AAVEUSDT_2021-05-04_1d.csv
# │       ├── AAVEUSDT_2021-05-05_1d.csv
# │       ├── AAVEUSDT_2021-05-06_1d.csv
# │       ├── AAVEUSDT_2021-05-07_1d.csv
# │       ├── AAVEUSDT_2021-05-08_1d.csv
# │       ├── AAVEUSDT_2021-05-09_1d.csv
# │       ├── AAVEUSDT_2021-05-10_1d.csv
# │       ├── AAVEUSDT_2021-05-11_1d.csv
# │       ├── AAVEUSDT_2021-05-12_1d.csv
# │       ├── AAVEUSDT_2021-05-13_1d.csv
# │       ├── AAVEUSDT_2021-05-14_1d.csv
# │       ├── AAVEUSDT_2021-05-15_1d.csv
# │       ├── AAVEUSDT_2021-05-16_1d.csv
# │       ├── AAVEUSDT_2021-05-17_1d.csv
# │       ├── AAVEUSDT_2021-05-18_1d.csv
# │       ├── AAVEUSDT_2021-05-19_1d.csv
# │       ├── AAVEUSDT_2021-05-20_1d.csv
# │       ├── AAVEUSDT_2021-05-21_1d.csv
# │       ├── AAVEUSDT_2021-05-22_1d.csv
# │       ├── AAVEUSDT_2021-05-23_1d.csv
# │       ├── AAVEUSDT_2021-05-24_1d.csv
# │       ├── AAVEUSDT_2021-05-25_1d.csv
# │       ├── AAVEUSDT_2021-05-26_1d.csv
# │       ├── AAVEUSDT_2021-05-27_1d.csv
# │       ├── AAVEUSDT_2021-05-28_1d.csv
# │       ├── AAVEUSDT_2021-05-29_1d.csv
# │       ├── AAVEUSDT_2021-05-30_1d.csv
# │       ├── AAVEUSDT_2021-05-31_1d.csv
# │       ├── AAVEUSDT_2021-06-01_1d.csv
# │       ├── AAVEUSDT_2021-06-02_1d.csv
# │       ├── AAVEUSDT_2021-06-03_1d.csv
# │       ├── AAVEUSDT_2021-06-04_1d.csv
# │       ├── AAVEUSDT_2021-06-05_1d.csv
# │       ├── AAVEUSDT_2021-06-06_1d.csv
# │       ├── AAVEUSDT_2021-06-07_1d.csv
# │       ├── AAVEUSDT_2021-06-08_1d.csv
# │       ├── AAVEUSDT_2021-06-09_1d.csv
# │       ├── AAVEUSDT_2021-06-10_1d.csv
# │       ├── AAVEUSDT_2021-06-11_1d.csv
# │       ├── AAVEUSDT_2021-06-12_1d.csv
# │       ├── AAVEUSDT_2021-06-13_1d.csv
# │       ├── AAVEUSDT_2021-06-14_1d.csv
# │       ├── AAVEUSDT_2021-06-15_1d.csv
# │       ├── AAVEUSDT_2021-06-16_1d.csv
# │       ├── AAVEUSDT_2021-06-17_1d.csv
# │       ├── AAVEUSDT_2021-06-18_1d.csv
# │       ├── AAVEUSDT_2021-06-19_1d.csv
# │       ├── AAVEUSDT_2021-06-20_1d.csv
# │       ├── AAVEUSDT_2021-06-21_1d.csv
# │       ├── AAVEUSDT_2021-06-22_1d.csv
# │       ├── AAVEUSDT_2021-06-23_1d.csv
# │       ├── AAVEUSDT_2021-06-24_1d.csv
# │       ├── AAVEUSDT_2021-06-25_1d.csv
# │       ├── AAVEUSDT_2021-06-26_1d.csv
# │       ├── AAVEUSDT_2021-06-27_1d.csv
# │       ├── AAVEUSDT_2021-06-28_1d.csv
# │       ├── AAVEUSDT_2021-06-29_1d.csv
# │       ├── AAVEUSDT_2021-06-30_1d.csv
# │       ├── AAVEUSDT_2021-07-01_1d.csv
# │       ├── AAVEUSDT_2021-07-02_1d.csv
# │       ├── AAVEUSDT_2021-07-03_1d.csv
# │       ├── AAVEUSDT_2021-07-04_1d.csv
# │       ├── AAVEUSDT_2021-07-05_1d.csv
# │       ├── AAVEUSDT_2021-07-06_1d.csv
# │       ├── AAVEUSDT_2021-07-07_1d.csv
# │       ├── AAVEUSDT_2021-07-08_1d.csv
# │       ├── AAVEUSDT_2021-07-09_1d.csv
# │       ├── AAVEUSDT_2021-07-10_1d.csv
# │       ├── AAVEUSDT_2021-07-11_1d.csv
# │       ├── AAVEUSDT_2021-07-12_1d.csv
# │       ├── AAVEUSDT_2021-07-13_1d.csv
# │       ├── AAVEUSDT_2021-07-14_1d.csv
# │       ├── AAVEUSDT_2021-07-15_1d.csv
# │       ├── AAVEUSDT_2021-07-16_1d.csv
# │       ├── AAVEUSDT_2021-07-17_1d.csv
# │       ├── AAVEUSDT_2021-07-18_1d.csv
# │       ├── AAVEUSDT_2021-07-19_1d.csv
# │       ├── AAVEUSDT_2021-07-20_1d.csv
# │       ├── AAVEUSDT_2021-07-21_1d.csv
# │       ├── AAVEUSDT_2021-07-22_1d.csv
# │       ├── AAVEUSDT_2021-07-23_1d.csv
# │       ├── AAVEUSDT_2021-07-24_1d.csv
# │       ├── AAVEUSDT_2021-07-25_1d.csv
# │       ├── AAVEUSDT_2021-07-26_1d.csv
# │       ├── AAVEUSDT_2021-07-27_1d.csv
# │       ├── AAVEUSDT_2021-07-28_1d.csv
# │       ├── AAVEUSDT_2021-07-29_1d.csv
# │       ├── AAVEUSDT_2021-07-30_1d.csv
# │       ├── AAVEUSDT_2021-07-31_1d.csv
# │       ├── AAVEUSDT_2021-08-01_1d.csv
# │       ├── AAVEUSDT_2021-08-02_1d.csv
# │       ├── AAVEUSDT_2021-08-03_1d.csv
# │       ├── AAVEUSDT_2021-08-04_1d.csv
# │       ├── AAVEUSDT_2021-08-05_1d.csv
# │       ├── AAVEUSDT_2021-08-06_1d.csv
# │       ├── AAVEUSDT_2021-08-07_1d.csv
# │       ├── AAVEUSDT_2021-08-08_1d.csv
# │       ├── AAVEUSDT_2021-08-09_1d.csv
# │       ├── AAVEUSDT_2021-08-10_1d.csv
# │       ├── AAVEUSDT_2021-08-11_1d.csv
# │       ├── AAVEUSDT_2021-08-12_1d.csv
# │       ├── AAVEUSDT_2021-08-13_1d.csv
# │       ├── AAVEUSDT_2021-08-14_1d.csv
# │       ├── AAVEUSDT_2021-08-15_1d.csv
# │       ├── AAVEUSDT_2021-08-16_1d.csv
# │       ├── AAVEUSDT_2021-08-17_1d.csv
# │       ├── AAVEUSDT_2021-08-18_1d.csv
# │       ├── AAVEUSDT_2021-08-19_1d.csv
# │       ├── AAVEUSDT_2021-08-20_1d.csv
# │       ├── AAVEUSDT_2021-08-21_1d.csv
# │       ├── AAVEUSDT_2021-08-22_1d.csv
# │       ├── AAVEUSDT_2021-08-23_1d.csv
# │       ├── AAVEUSDT_2021-08-24_1d.csv
# │       ├── AAVEUSDT_2021-08-25_1d.csv
# │       ├── AAVEUSDT_2021-08-26_1d.csv
# │       ├── AAVEUSDT_2021-08-27_1d.csv
# │       ├── AAVEUSDT_2021-08-28_1d.csv
# │       ├── AAVEUSDT_2021-08-29_1d.csv
# │       ├── AAVEUSDT_2021-08-30_1d.csv
# │       ├── AAVEUSDT_2021-08-31_1d.csv
# │       ├── AAVEUSDT_2021-09-01_1d.csv
# │       ├── AAVEUSDT_2021-09-02_1d.csv
# │       ├── AAVEUSDT_2021-09-03_1d.csv
# │       ├── AAVEUSDT_2021-09-04_1d.csv
# │       ├── AAVEUSDT_2021-09-05_1d.csv
# │       ├── AAVEUSDT_2021-09-06_1d.csv
# │       ├── AAVEUSDT_2021-09-07_1d.csv
# │       ├── AAVEUSDT_2021-09-08_1d.csv
# │       ├── AAVEUSDT_2021-09-09_1d.csv
# │       ├── AAVEUSDT_2021-09-10_1d.csv
# │       ├── AAVEUSDT_2021-09-11_1d.csv
# │       ├── AAVEUSDT_2021-09-12_1d.csv
# │       ├── AAVEUSDT_2021-09-13_1d.csv
# │       ├── AAVEUSDT_2021-09-14_1d.csv
# │       ├── AAVEUSDT_2021-09-15_1d.csv
# │       ├── AAVEUSDT_2021-09-16_1d.csv
# │       ├── AAVEUSDT_2021-09-17_1d.csv
# │       ├── AAVEUSDT_2021-09-18_1d.csv
# │       ├── AAVEUSDT_2021-09-19_1d.csv
# │       ├── AAVEUSDT_2021-09-20_1d.csv
# │       ├── AAVEUSDT_2021-09-21_1d.csv
# │       ├── AAVEUSDT_2021-09-22_1d.csv
# │       ├── AAVEUSDT_2021-09-23_1d.csv
# │       ├── AAVEUSDT_2021-09-24_1d.csv
# │       ├── AAVEUSDT_2021-09-25_1d.csv
# │       ├── AAVEUSDT_2021-09-26_1d.csv
# │       ├── AAVEUSDT_2021-09-27_1d.csv
# │       ├── AAVEUSDT_2021-09-28_1d.csv
# │       ├── AAVEUSDT_2021-09-29_1d.csv
# │       ├── AAVEUSDT_2021-09-30_1d.csv
# │       ├── AAVEUSDT_2021-10-01_1d.csv
# │       ├── AAVEUSDT_2021-10-02_1d.csv
# │       ├── AAVEUSDT_2021-10-03_1d.csv
# │       ├── AAVEUSDT_2021-10-04_1d.csv
# │       ├── AAVEUSDT_2021-10-05_1d.csv
# │       ├── AAVEUSDT_2021-10-06_1d.csv
# │       ├── AAVEUSDT_2021-10-07_1d.csv
# │       ├── AAVEUSDT_2021-10-08_1d.csv
# │       ├── AAVEUSDT_2021-10-09_1d.csv
# │       ├── AAVEUSDT_2021-10-10_1d.csv
# │       ├── AAVEUSDT_2021-10-11_1d.csv
# │       ├── AAVEUSDT_2021-10-12_1d.csv
# │       ├── AAVEUSDT_2021-10-13_1d.csv
# │       ├── AAVEUSDT_2021-10-14_1d.csv
# │       ├── AAVEUSDT_2021-10-15_1d.csv
# │       ├── AAVEUSDT_2021-10-16_1d.csv
# │       ├── AAVEUSDT_2021-10-17_1d.csv
# │       ├── AAVEUSDT_2021-10-18_1d.csv
# │       ├── AAVEUSDT_2021-10-19_1d.csv
# │       ├── AAVEUSDT_2021-10-20_1d.csv
# │       ├── AAVEUSDT_2021-10-21_1d.csv
# │       ├── AAVEUSDT_2021-10-22_1d.csv
# │       ├── AAVEUSDT_2021-10-23_1d.csv
# │       ├── AAVEUSDT_2021-10-24_1d.csv
# │       ├── AAVEUSDT_2021-10-25_1d.csv
# │       ├── AAVEUSDT_2021-10-26_1d.csv
# │       ├── AAVEUSDT_2021-10-27_1d.csv
# │       ├── AAVEUSDT_2021-10-28_1d.csv
# │       ├── AAVEUSDT_2021-10-29_1d.csv
# │       ├── AAVEUSDT_2021-10-30_1d.csv
# │       ├── AAVEUSDT_2021-10-31_1d.csv
# │       ├── AAVEUSDT_2021-11-01_1d.csv
# │       ├── AAVEUSDT_2021-11-02_1d.csv
# │       ├── AAVEUSDT_2021-11-03_1d.csv
# │       ├── AAVEUSDT_2021-11-04_1d.csv
# │       ├── AAVEUSDT_2021-11-05_1d.csv
# │       ├── AAVEUSDT_2021-11-06_1d.csv
# │       ├── AAVEUSDT_2021-11-07_1d.csv
# │       ├── AAVEUSDT_2021-11-08_1d.csv
# │       ├── AAVEUSDT_2021-11-09_1d.csv
# │       ├── AAVEUSDT_2021-11-10_1d.csv
# │       ├── AAVEUSDT_2021-11-11_1d.csv
# │       ├── AAVEUSDT_2021-11-12_1d.csv
# │       ├── AAVEUSDT_2021-11-13_1d.csv
# │       ├── AAVEUSDT_2021-11-14_1d.csv
# │       ├── AAVEUSDT_2021-11-15_1d.csv
# │       ├── AAVEUSDT_2021-11-16_1d.csv
# │       ├── AAVEUSDT_2021-11-17_1d.csv
# │       ├── AAVEUSDT_2021-11-18_1d.csv
# │       ├── AAVEUSDT_2021-11-19_1d.csv
# │       ├── AAVEUSDT_2021-11-20_1d.csv
# │       ├── AAVEUSDT_2021-11-21_1d.csv
# │       ├── AAVEUSDT_2021-11-22_1d.csv
# │       ├── AAVEUSDT_2021-11-23_1d.csv
# │       ├── AAVEUSDT_2021-11-24_1d.csv
# │       ├── AAVEUSDT_2021-11-25_1d.csv
# │       ├── AAVEUSDT_2021-11-26_1d.csv
# │       ├── AAVEUSDT_2021-11-27_1d.csv
# │       ├── AAVEUSDT_2021-11-28_1d.csv
# │       ├── AAVEUSDT_2021-11-29_1d.csv
# │       ├── AAVEUSDT_2021-11-30_1d.csv
# │       ├── AAVEUSDT_2021-12-01_1d.csv
# │       ├── AAVEUSDT_2021-12-02_1d.csv
# │       ├── AAVEUSDT_2021-12-03_1d.csv
# │       ├── AAVEUSDT_2021-12-04_1d.csv
# │       ├── AAVEUSDT_2021-12-05_1d.csv
# │       ├── AAVEUSDT_2021-12-06_1d.csv
# │       ├── AAVEUSDT_2021-12-07_1d.csv
# │       ├── AAVEUSDT_2021-12-08_1d.csv
# │       ├── AAVEUSDT_2021-12-09_1d.csv
# │       ├── AAVEUSDT_2021-12-10_1d.csv
# │       ├── AAVEUSDT_2021-12-11_1d.csv
# │       ├── AAVEUSDT_2021-12-12_1d.csv
# │       ├── AAVEUSDT_2021-12-13_1d.csv
# │       ├── AAVEUSDT_2021-12-14_1d.csv
# │       ├── AAVEUSDT_2021-12-15_1d.csv
# │       ├── AAVEUSDT_2021-12-16_1d.csv
# │       ├── AAVEUSDT_2021-12-17_1d.csv
# │       ├── AAVEUSDT_2021-12-18_1d.csv
# │       ├── AAVEUSDT_2021-12-19_1d.csv
# │       ├── AAVEUSDT_2021-12-20_1d.csv
# │       ├── AAVEUSDT_2021-12-21_1d.csv
# │       ├── AAVEUSDT_2021-12-22_1d.csv
# │       ├── AAVEUSDT_2021-12-23_1d.csv
# │       ├── AAVEUSDT_2021-12-24_1d.csv
# │       ├── AAVEUSDT_2021-12-25_1d.csv
# │       ├── AAVEUSDT_2021-12-26_1d.csv
# │       ├── AAVEUSDT_2021-12-27_1d.csv
# │       ├── AAVEUSDT_2021-12-28_1d.csv
# │       ├── AAVEUSDT_2021-12-29_1d.csv
# │       ├── AAVEUSDT_2021-12-30_1d.csv
# │       ├── AAVEUSDT_2021-12-31_1d.csv
# │       ├── AAVEUSDT_2022-01-01_1d.csv
# │       ├── AAVEUSDT_2022-01-02_1d.csv
# │       ├── AAVEUSDT_2022-01-03_1d.csv
# │       ├── AAVEUSDT_2022-01-04_1d.csv
# │       ├── AAVEUSDT_2022-01-05_1d.csv
# │       ├── AAVEUSDT_2022-01-06_1d.csv
# │       ├── AAVEUSDT_2022-01-07_1d.csv
# │       ├── AAVEUSDT_2022-01-08_1d.csv
# │       ├── AAVEUSDT_2022-01-09_1d.csv
# │       ├── AAVEUSDT_2022-01-10_1d.csv
# │       ├── AAVEUSDT_2022-01-11_1d.csv
# │       ├── AAVEUSDT_2022-01-12_1d.csv
# │       ├── AAVEUSDT_2022-01-13_1d.csv
# │       ├── AAVEUSDT_2022-01-14_1d.csv
# │       ├── AAVEUSDT_2022-01-15_1d.csv
# │       ├── AAVEUSDT_2022-01-16_1d.csv
# │       ├── AAVEUSDT_2022-01-17_1d.csv
# │       ├── AAVEUSDT_2022-01-18_1d.csv
# │       ├── AAVEUSDT_2022-01-19_1d.csv
# │       ├── AAVEUSDT_2022-01-20_1d.csv
# │       ├── AAVEUSDT_2022-01-21_1d.csv
# │       ├── AAVEUSDT_2022-01-22_1d.csv
# │       ├── AAVEUSDT_2022-01-23_1d.csv
# │       ├── AAVEUSDT_2022-01-24_1d.csv
# │       ├── AAVEUSDT_2022-01-25_1d.csv
# │       ├── AAVEUSDT_2022-01-26_1d.csv
# │       ├── AAVEUSDT_2022-01-27_1d.csv
# │       ├── AAVEUSDT_2022-01-28_1d.csv
# │       ├── AAVEUSDT_2022-01-29_1d.csv
# │       ├── AAVEUSDT_2022-01-30_1d.csv
# │       ├── AAVEUSDT_2022-01-31_1d.csv
# │       ├── AAVEUSDT_2022-02-01_1d.csv
# │       ├── AAVEUSDT_2022-02-02_1d.csv
# │       ├── AAVEUSDT_2022-02-03_1d.csv
# │       ├── AAVEUSDT_2022-02-04_1d.csv
# │       ├── AAVEUSDT_2022-02-05_1d.csv
# │       ├── AAVEUSDT_2022-02-06_1d.csv
# │       ├── AAVEUSDT_2022-02-07_1d.csv
# │       ├── AAVEUSDT_2022-02-08_1d.csv
# │       ├── AAVEUSDT_2022-02-09_1d.csv
# │       ├── AAVEUSDT_2022-02-10_1d.csv
# │       ├── AAVEUSDT_2022-02-11_1d.csv
# │       ├── AAVEUSDT_2022-02-12_1d.csv
# │       ├── AAVEUSDT_2022-02-13_1d.csv
# │       ├── AAVEUSDT_2022-02-14_1d.csv
# │       ├── AAVEUSDT_2022-02-15_1d.csv
# │       ├── AAVEUSDT_2022-02-16_1d.csv
# │       ├── AAVEUSDT_2022-02-17_1d.csv
# │       ├── AAVEUSDT_2022-02-18_1d.csv
# │       ├── AAVEUSDT_2022-02-19_1d.csv
# │       ├── AAVEUSDT_2022-02-20_1d.csv
# │       ├── AAVEUSDT_2022-02-21_1d.csv
# │       ├── AAVEUSDT_2022-02-22_1d.csv
# │       ├── AAVEUSDT_2022-02-23_1d.csv
# │       ├── AAVEUSDT_2022-02-24_1d.csv
# │       ├── AAVEUSDT_2022-02-25_1d.csv
# │       ├── AAVEUSDT_2022-02-26_1d.csv
# │       ├── AAVEUSDT_2022-02-27_1d.csv
# │       ├── AAVEUSDT_2022-02-28_1d.csv
# │       ├── AAVEUSDT_2022-03-01_1d.csv
# │       ├── AAVEUSDT_2022-03-02_1d.csv
# │       ├── AAVEUSDT_2022-03-03_1d.csv
# │       ├── AAVEUSDT_2022-03-04_1d.csv
# │       ├── AAVEUSDT_2022-03-05_1d.csv
# │       ├── AAVEUSDT_2022-03-06_1d.csv
# │       ├── AAVEUSDT_2022-03-07_1d.csv
# │       ├── AAVEUSDT_2022-03-08_1d.csv
# │       ├── AAVEUSDT_2022-03-09_1d.csv
# │       ├── AAVEUSDT_2022-03-10_1d.csv
# │       ├── AAVEUSDT_2022-03-11_1d.csv
# │       ├── AAVEUSDT_2022-03-12_1d.csv
# │       ├── AAVEUSDT_2022-03-13_1d.csv
# │       ├── AAVEUSDT_2022-03-14_1d.csv
# │       ├── AAVEUSDT_2022-03-15_1d.csv
# │       ├── AAVEUSDT_2022-03-16_1d.csv
# │       ├── AAVEUSDT_2022-03-17_1d.csv
# │       ├── AAVEUSDT_2022-03-18_1d.csv
# │       ├── AAVEUSDT_2022-03-19_1d.csv
# │       ├── AAVEUSDT_2022-03-20_1d.csv
# │       ├── AAVEUSDT_2022-03-21_1d.csv
# │       ├── AAVEUSDT_2022-03-22_1d.csv
# │       ├── AAVEUSDT_2022-03-23_1d.csv
# │       ├── AAVEUSDT_2022-03-24_1d.csv
# │       ├── AAVEUSDT_2022-03-25_1d.csv
# │       ├── AAVEUSDT_2022-03-26_1d.csv
# │       ├── AAVEUSDT_2022-03-27_1d.csv
# │       ├── AAVEUSDT_2022-03-28_1d.csv
# │       ├── AAVEUSDT_2022-03-29_1d.csv
# │       ├── AAVEUSDT_2022-03-30_1d.csv
# │       ├── AAVEUSDT_2022-03-31_1d.csv
# │       ├── AAVEUSDT_2022-04-01_1d.csv
# │       ├── AAVEUSDT_2022-04-02_1d.csv
# │       ├── AAVEUSDT_2022-04-03_1d.csv
# │       ├── AAVEUSDT_2022-04-04_1d.csv
# │       ├── AAVEUSDT_2022-04-05_1d.csv
# │       ├── AAVEUSDT_2022-04-06_1d.csv
# │       ├── AAVEUSDT_2022-04-07_1d.csv
# │       ├── AAVEUSDT_2022-04-08_1d.csv
# │       ├── AAVEUSDT_2022-04-09_1d.csv
# │       ├── AAVEUSDT_2022-04-10_1d.csv
# │       ├── AAVEUSDT_2022-04-11_1d.csv
# │       ├── AAVEUSDT_2022-04-12_1d.csv
# │       ├── AAVEUSDT_2022-04-13_1d.csv
# │       ├── AAVEUSDT_2022-04-14_1d.csv
# │       ├── AAVEUSDT_2022-04-15_1d.csv
# │       ├── AAVEUSDT_2022-04-16_1d.csv
# │       ├── AAVEUSDT_2022-04-17_1d.csv
# │       ├── AAVEUSDT_2022-04-18_1d.csv
# │       ├── AAVEUSDT_2022-04-19_1d.csv
# │       ├── AAVEUSDT_2022-04-20_1d.csv
# │       ├── AAVEUSDT_2022-04-21_1d.csv
# │       ├── AAVEUSDT_2022-04-22_1d.csv
# │       ├── AAVEUSDT_2022-04-23_1d.csv
# │       ├── AAVEUSDT_2022-04-24_1d.csv
# │       ├── AAVEUSDT_2022-04-25_1d.csv
# │       ├── AAVEUSDT_2022-04-26_1d.csv
# │       ├── AAVEUSDT_2022-04-27_1d.csv
# │       ├── AAVEUSDT_2022-04-28_1d.csv
# │       ├── AAVEUSDT_2022-04-29_1d.csv
# │       ├── AAVEUSDT_2022-04-30_1d.csv
# │       ├── AAVEUSDT_2022-05-01_1d.csv
# │       ├── AAVEUSDT_2022-05-02_1d.csv
# │       ├── AAVEUSDT_2022-05-03_1d.csv
# │       ├── AAVEUSDT_2022-05-04_1d.csv
# │       ├── AAVEUSDT_2022-05-05_1d.csv
# │       ├── AAVEUSDT_2022-05-06_1d.csv
# │       ├── AAVEUSDT_2022-05-07_1d.csv
# │       ├── AAVEUSDT_2022-05-08_1d.csv
# │       ├── AAVEUSDT_2022-05-09_1d.csv
# │       ├── AAVEUSDT_2022-05-10_1d.csv
# │       ├── AAVEUSDT_2022-05-11_1d.csv
# │       ├── AAVEUSDT_2022-05-12_1d.csv
# │       ├── AAVEUSDT_2022-05-13_1d.csv
# │       ├── AAVEUSDT_2022-05-14_1d.csv
# │       ├── AAVEUSDT_2022-05-15_1d.csv
# │       ├── AAVEUSDT_2022-05-16_1d.csv
# │       ├── AAVEUSDT_2022-05-17_1d.csv
# │       ├── AAVEUSDT_2022-05-18_1d.csv
# │       ├── AAVEUSDT_2022-05-19_1d.csv
# │       ├── AAVEUSDT_2022-05-20_1d.csv
# │       ├── AAVEUSDT_2022-05-21_1d.csv
# │       ├── AAVEUSDT_2022-05-22_1d.csv
# │       ├── AAVEUSDT_2022-05-23_1d.csv
# │       ├── AAVEUSDT_2022-05-24_1d.csv
# │       ├── AAVEUSDT_2022-05-25_1d.csv
# │       ├── AAVEUSDT_2022-05-26_1d.csv
# │       ├── AAVEUSDT_2022-05-27_1d.csv
# │       ├── AAVEUSDT_2022-05-28_1d.csv
# │       ├── AAVEUSDT_2022-05-29_1d.csv
# │       ├── AAVEUSDT_2022-05-30_1d.csv
# │       ├── AAVEUSDT_2022-05-31_1d.csv
# │       ├── AAVEUSDT_2022-06-01_1d.csv
# │       ├── AAVEUSDT_2022-06-02_1d.csv
# │       ├── AAVEUSDT_2022-06-03_1d.csv
# │       ├── AAVEUSDT_2022-06-04_1d.csv
# │       ├── AAVEUSDT_2022-06-05_1d.csv
# │       ├── AAVEUSDT_2022-06-06_1d.csv
# │       ├── AAVEUSDT_2022-06-07_1d.csv
# │       ├── AAVEUSDT_2022-06-08_1d.csv
# │       ├── AAVEUSDT_2022-06-09_1d.csv
# │       ├── AAVEUSDT_2022-06-10_1d.csv
# │       ├── AAVEUSDT_2022-06-11_1d.csv
# │       ├── AAVEUSDT_2022-06-12_1d.csv
# │       ├── AAVEUSDT_2022-06-13_1d.csv
# │       ├── AAVEUSDT_2022-06-14_1d.csv
# │       ├── AAVEUSDT_2022-06-15_1d.csv
# │       ├── AAVEUSDT_2022-06-16_1d.csv
# │       ├── AAVEUSDT_2022-06-17_1d.csv
# │       ├── AAVEUSDT_2022-06-18_1d.csv
# │       ├── AAVEUSDT_2022-06-19_1d.csv
# │       ├── AAVEUSDT_2022-06-20_1d.csv
# │       ├── AAVEUSDT_2022-06-21_1d.csv
# │       ├── AAVEUSDT_2022-06-22_1d.csv
# │       ├── AAVEUSDT_2022-06-23_1d.csv
# │       ├── AAVEUSDT_2022-06-24_1d.csv
# │       ├── AAVEUSDT_2022-06-25_1d.csv
# │       ├── AAVEUSDT_2022-06-26_1d.csv
# │       ├── AAVEUSDT_2022-06-27_1d.csv
# │       ├── AAVEUSDT_2022-06-28_1d.csv
# │       ├── AAVEUSDT_2022-06-29_1d.csv
# │       ├── AAVEUSDT_2022-06-30_1d.csv
# │       ├── AAVEUSDT_2022-07-01_1d.csv
# │       ├── AAVEUSDT_2022-07-02_1d.csv
# │       ├── AAVEUSDT_2022-07-03_1d.csv
# │       ├── AAVEUSDT_2022-07-04_1d.csv
# │       ├── AAVEUSDT_2022-07-05_1d.csv
# │       ├── AAVEUSDT_2022-07-06_1d.csv
# │       ├── AAVEUSDT_2022-07-07_1d.csv
# │       ├── AAVEUSDT_2022-07-08_1d.csv
# │       ├── AAVEUSDT_2022-07-09_1d.csv
# │       ├── AAVEUSDT_2022-07-10_1d.csv
# │       ├── AAVEUSDT_2022-07-11_1d.csv
# │       ├── AAVEUSDT_2022-07-12_1d.csv
# │       ├── AAVEUSDT_2022-07-13_1d.csv
# │       ├── AAVEUSDT_2022-07-14_1d.csv
# │       ├── AAVEUSDT_2022-07-15_1d.csv
# │       ├── AAVEUSDT_2022-07-16_1d.csv
# │       ├── AAVEUSDT_2022-07-17_1d.csv
# │       ├── AAVEUSDT_2022-07-18_1d.csv
# │       ├── AAVEUSDT_2022-07-19_1d.csv
# │       ├── AAVEUSDT_2022-07-20_1d.csv
# │       ├── AAVEUSDT_2022-07-21_1d.csv
# │       ├── AAVEUSDT_2022-07-22_1d.csv
# │       ├── AAVEUSDT_2022-07-23_1d.csv
# │       ├── AAVEUSDT_2022-07-24_1d.csv
# │       ├── AAVEUSDT_2022-07-25_1d.csv
# │       ├── AAVEUSDT_2022-07-26_1d.csv
# │       ├── AAVEUSDT_2022-07-27_1d.csv
# │       ├── AAVEUSDT_2022-07-28_1d.csv
# │       ├── AAVEUSDT_2022-07-29_1d.csv
# │       ├── AAVEUSDT_2022-07-30_1d.csv
# │       ├── AAVEUSDT_2022-07-31_1d.csv
# │       ├── AAVEUSDT_2022-08-01_1d.csv
# │       ├── AAVEUSDT_2022-08-02_1d.csv
# │       ├── AAVEUSDT_2022-08-03_1d.csv
# │       ├── AAVEUSDT_2022-08-04_1d.csv
# │       ├── AAVEUSDT_2022-08-05_1d.csv
# │       ├── AAVEUSDT_2022-08-06_1d.csv
# │       ├── AAVEUSDT_2022-08-07_1d.csv
# │       ├── AAVEUSDT_2022-08-08_1d.csv
# │       ├── AAVEUSDT_2022-08-09_1d.csv
# │       ├── AAVEUSDT_2022-08-10_1d.csv
# │       ├── AAVEUSDT_2022-08-11_1d.csv
# │       ├── AAVEUSDT_2022-08-12_1d.csv
# │       ├── AAVEUSDT_2022-08-13_1d.csv
# │       ├── AAVEUSDT_2022-08-14_1d.csv
# │       ├── AAVEUSDT_2022-08-15_1d.csv
# │       ├── AAVEUSDT_2022-08-16_1d.csv
# │       ├── AAVEUSDT_2022-08-17_1d.csv
# │       ├── AAVEUSDT_2022-08-18_1d.csv
# │       ├── AAVEUSDT_2022-08-19_1d.csv
# │       ├── AAVEUSDT_2022-08-20_1d.csv
# │       ├── AAVEUSDT_2022-08-21_1d.csv
# │       ├── AAVEUSDT_2022-08-22_1d.csv
# │       ├── AAVEUSDT_2022-08-23_1d.csv
# │       ├── AAVEUSDT_2022-08-24_1d.csv
# │       ├── AAVEUSDT_2022-08-25_1d.csv
# │       ├── AAVEUSDT_2022-08-26_1d.csv
# │       ├── AAVEUSDT_2022-08-27_1d.csv
# │       ├── AAVEUSDT_2022-08-28_1d.csv
# │       ├── AAVEUSDT_2022-08-29_1d.csv
# │       ├── AAVEUSDT_2022-08-30_1d.csv
# │       ├── AAVEUSDT_2022-08-31_1d.csv
# │       ├── AAVEUSDT_2022-09-01_1d.csv
# │       ├── AAVEUSDT_2022-09-02_1d.csv
# │       ├── AAVEUSDT_2022-09-03_1d.csv
# │       ├── AAVEUSDT_2022-09-04_1d.csv
# │       ├── AAVEUSDT_2022-09-05_1d.csv
# │       ├── AAVEUSDT_2022-09-06_1d.csv
# │       ├── AAVEUSDT_2022-09-07_1d.csv
# │       ├── AAVEUSDT_2022-09-08_1d.csv
# │       ├── AAVEUSDT_2022-09-09_1d.csv
# │       ├── AAVEUSDT_2022-09-10_1d.csv
# │       ├── AAVEUSDT_2022-09-11_1d.csv
# │       ├── AAVEUSDT_2022-09-12_1d.csv
# │       ├── AAVEUSDT_2022-09-13_1d.csv
# │       ├── AAVEUSDT_2022-09-14_1d.csv
# │       ├── AAVEUSDT_2022-09-15_1d.csv
# │       ├── AAVEUSDT_2022-09-16_1d.csv
# │       ├── AAVEUSDT_2022-09-17_1d.csv
# │       ├── AAVEUSDT_2022-09-18_1d.csv
# │       ├── AAVEUSDT_2022-09-19_1d.csv
# │       ├── AAVEUSDT_2022-09-20_1d.csv
# │       ├── AAVEUSDT_2022-09-21_1d.csv
# │       ├── AAVEUSDT_2022-09-22_1d.csv
# │       ├── AAVEUSDT_2022-09-23_1d.csv
# │       ├── AAVEUSDT_2022-09-24_1d.csv
# │       ├── AAVEUSDT_2022-09-25_1d.csv
# │       ├── AAVEUSDT_2022-09-26_1d.csv
# │       ├── AAVEUSDT_2022-09-27_1d.csv
# │       ├── AAVEUSDT_2022-09-28_1d.csv
# │       ├── AAVEUSDT_2022-09-29_1d.csv
# │       ├── AAVEUSDT_2022-09-30_1d.csv
# │       ├── AAVEUSDT_2022-10-01_1d.csv
# │       ├── AAVEUSDT_2022-10-02_1d.csv
# │       ├── AAVEUSDT_2022-10-03_1d.csv
# │       ├── AAVEUSDT_2022-10-04_1d.csv
# │       ├── AAVEUSDT_2022-10-05_1d.csv
# │       ├── AAVEUSDT_2022-10-06_1d.csv
# │       ├── AAVEUSDT_2022-10-07_1d.csv
# │       ├── AAVEUSDT_2022-10-08_1d.csv
# │       ├── AAVEUSDT_2022-10-09_1d.csv
# │       ├── AAVEUSDT_2022-10-10_1d.csv
# │       ├── AAVEUSDT_2022-10-11_1d.csv
# │       ├── AAVEUSDT_2022-10-12_1d.csv
# │       ├── AAVEUSDT_2022-10-13_1d.csv
# │       ├── AAVEUSDT_2022-10-14_1d.csv
# │       ├── AAVEUSDT_2022-10-15_1d.csv
# │       ├── AAVEUSDT_2022-10-16_1d.csv
# │       ├── AAVEUSDT_2022-10-17_1d.csv
# │       ├── AAVEUSDT_2022-10-18_1d.csv
# │       ├── AAVEUSDT_2022-10-19_1d.csv
# │       ├── AAVEUSDT_2022-10-20_1d.csv
# │       ├── AAVEUSDT_2022-10-21_1d.csv
# │       ├── AAVEUSDT_2022-10-22_1d.csv
# │       ├── AAVEUSDT_2022-10-23_1d.csv
# │       ├── AAVEUSDT_2022-10-24_1d.csv
# │       ├── AAVEUSDT_2022-10-25_1d.csv
# │       ├── AAVEUSDT_2022-10-26_1d.csv
# │       ├── AAVEUSDT_2022-10-27_1d.csv
# │       ├── AAVEUSDT_2022-10-28_1d.csv
# │       ├── AAVEUSDT_2022-10-29_1d.csv
# │       ├── AAVEUSDT_2022-10-30_1d.csv
# │       ├── AAVEUSDT_2022-10-31_1d.csv
# │       ├── AAVEUSDT_2022-11-01_1d.csv
# │       ├── AAVEUSDT_2022-11-02_1d.csv
# │       ├── AAVEUSDT_2022-11-03_1d.csv
# │       ├── AAVEUSDT_2022-11-04_1d.csv
# │       ├── AAVEUSDT_2022-11-05_1d.csv
# │       ├── AAVEUSDT_2022-11-06_1d.csv
# │       ├── AAVEUSDT_2022-11-07_1d.csv
# │       ├── AAVEUSDT_2022-11-08_1d.csv
# │       ├── AAVEUSDT_2022-11-09_1d.csv
# │       ├── AAVEUSDT_2022-11-10_1d.csv
# │       ├── AAVEUSDT_2022-11-11_1d.csv
# │       ├── AAVEUSDT_2022-11-12_1d.csv
# │       ├── AAVEUSDT_2022-11-13_1d.csv
# │       ├── AAVEUSDT_2022-11-14_1d.csv
# │       ├── AAVEUSDT_2022-11-15_1d.csv
# │       ├── AAVEUSDT_2022-11-16_1d.csv
# │       ├── AAVEUSDT_2022-11-17_1d.csv
# │       ├── AAVEUSDT_2022-11-18_1d.csv
# │       ├── AAVEUSDT_2022-11-19_1d.csv
# │       ├── AAVEUSDT_2022-11-20_1d.csv
# │       ├── AAVEUSDT_2022-11-21_1d.csv
# │       ├── AAVEUSDT_2022-11-22_1d.csv
# │       ├── AAVEUSDT_2022-11-23_1d.csv
# │       ├── AAVEUSDT_2022-11-24_1d.csv
# │       ├── AAVEUSDT_2022-11-25_1d.csv
# │       ├── AAVEUSDT_2022-11-26_1d.csv
# │       ├── AAVEUSDT_2022-11-27_1d.csv
# │       ├── AAVEUSDT_2022-11-28_1d.csv
# │       ├── AAVEUSDT_2022-11-29_1d.csv
# │       ├── AAVEUSDT_2022-11-30_1d.csv
# │       ├── AAVEUSDT_2022-12-01_1d.csv
# │       ├── AAVEUSDT_2022-12-02_1d.csv
# │       ├── AAVEUSDT_2022-12-03_1d.csv
# │       ├── AAVEUSDT_2022-12-04_1d.csv
# │       ├── AAVEUSDT_2022-12-05_1d.csv
# │       ├── AAVEUSDT_2022-12-06_1d.csv
# │       ├── AAVEUSDT_2022-12-07_1d.csv
# │       ├── AAVEUSDT_2022-12-08_1d.csv
# │       ├── AAVEUSDT_2022-12-09_1d.csv
# │       ├── AAVEUSDT_2022-12-10_1d.csv
# │       ├── AAVEUSDT_2022-12-11_1d.csv
# │       ├── AAVEUSDT_2022-12-12_1d.csv
# │       ├── AAVEUSDT_2022-12-13_1d.csv
# │       ├── AAVEUSDT_2022-12-14_1d.csv
# │       ├── AAVEUSDT_2022-12-15_1d.csv
# │       ├── AAVEUSDT_2022-12-16_1d.csv
# │       ├── AAVEUSDT_2022-12-17_1d.csv
# │       ├── AAVEUSDT_2022-12-18_1d.csv
# │       ├── AAVEUSDT_2022-12-19_1d.csv
# │       ├── AAVEUSDT_2022-12-20_1d.csv
# │       ├── AAVEUSDT_2022-12-21_1d.csv
# │       ├── AAVEUSDT_2022-12-22_1d.csv
# │       ├── AAVEUSDT_2022-12-23_1d.csv
# │       ├── AAVEUSDT_2022-12-24_1d.csv
# │       ├── AAVEUSDT_2022-12-25_1d.csv
# │       ├── AAVEUSDT_2022-12-26_1d.csv
# │       ├── AAVEUSDT_2022-12-27_1d.csv
# │       ├── AAVEUSDT_2022-12-28_1d.csv
# │       ├── AAVEUSDT_2022-12-29_1d.csv
# │       ├── AAVEUSDT_2022-12-30_1d.csv
# │       ├── AAVEUSDT_2022-12-31_1d.csv
# │       ├── AAVEUSDT_2023-01-01_1d.csv
# │       ├── AAVEUSDT_2023-01-02_1d.csv
# │       ├── AAVEUSDT_2023-01-03_1d.csv
# │       ├── AAVEUSDT_2023-01-04_1d.csv
# │       ├── AAVEUSDT_2023-01-05_1d.csv
# │       ├── AAVEUSDT_2023-01-06_1d.csv
# │       ├── AAVEUSDT_2023-01-07_1d.csv
# │       ├── AAVEUSDT_2023-01-08_1d.csv
# │       ├── AAVEUSDT_2023-01-09_1d.csv
# │       ├── AAVEUSDT_2023-01-10_1d.csv
# │       ├── AAVEUSDT_2023-01-11_1d.csv
# │       ├── AAVEUSDT_2023-01-12_1d.csv
# │       ├── AAVEUSDT_2023-01-13_1d.csv
# │       ├── AAVEUSDT_2023-01-14_1d.csv
# │       ├── AAVEUSDT_2023-01-15_1d.csv
# │       ├── AAVEUSDT_2023-01-16_1d.csv
# │       ├── AAVEUSDT_2023-01-17_1d.csv
# │       ├── AAVEUSDT_2023-01-18_1d.csv
# │       ├── AAVEUSDT_2023-01-19_1d.csv
# │       ├── AAVEUSDT_2023-01-20_1d.csv
# │       ├── AAVEUSDT_2023-01-21_1d.csv
# │       ├── AAVEUSDT_2023-01-22_1d.csv
# │       ├── AAVEUSDT_2023-01-23_1d.csv
# │       ├── AAVEUSDT_2023-01-24_1d.csv
# │       ├── AAVEUSDT_2023-01-25_1d.csv
# │       ├── AAVEUSDT_2023-01-26_1d.csv
# │       ├── AAVEUSDT_2023-01-27_1d.csv
# │       ├── AAVEUSDT_2023-01-28_1d.csv
# │       ├── AAVEUSDT_2023-01-29_1d.csv
# │       ├── AAVEUSDT_2023-01-30_1d.csv
# │       ├── AAVEUSDT_2023-01-31_1d.csv
# │       ├── AAVEUSDT_2023-02-01_1d.csv
# │       ├── AAVEUSDT_2023-02-02_1d.csv
# │       ├── AAVEUSDT_2023-02-03_1d.csv
# │       ├── AAVEUSDT_2023-02-04_1d.csv
# │       ├── AAVEUSDT_2023-02-05_1d.csv
# │       ├── AAVEUSDT_2023-02-06_1d.csv
# │       ├── AAVEUSDT_2023-02-07_1d.csv
# │       ├── AAVEUSDT_2023-02-08_1d.csv
# │       ├── AAVEUSDT_2023-02-09_1d.csv
# │       ├── AAVEUSDT_2023-02-10_1d.csv
# │       ├── AAVEUSDT_2023-02-11_1d.csv
# │       ├── AAVEUSDT_2023-02-12_1d.csv
# │       ├── AAVEUSDT_2023-02-13_1d.csv
# │       ├── AAVEUSDT_2023-02-14_1d.csv
# │       ├── AAVEUSDT_2023-02-15_1d.csv
# │       ├── AAVEUSDT_2023-02-16_1d.csv
# │       ├── AAVEUSDT_2023-02-17_1d.csv
# │       ├── AAVEUSDT_2023-02-18_1d.csv
# │       ├── AAVEUSDT_2023-02-19_1d.csv
# │       ├── AAVEUSDT_2023-02-20_1d.csv
# │       ├── AAVEUSDT_2023-02-21_1d.csv
# │       ├── AAVEUSDT_2023-02-22_1d.csv
# │       ├── AAVEUSDT_2023-02-23_1d.csv
# │       ├── AAVEUSDT_2023-02-24_1d.csv
# │       ├── AAVEUSDT_2023-02-25_1d.csv
# │       ├── AAVEUSDT_2023-02-26_1d.csv
# │       ├── AAVEUSDT_2023-02-27_1d.csv
# │       ├── AAVEUSDT_2023-02-28_1d.csv
# │       ├── AAVEUSDT_2023-03-01_1d.csv
# │       ├── AAVEUSDT_2023-03-02_1d.csv
# │       ├── AAVEUSDT_2023-03-03_1d.csv
# │       ├── AAVEUSDT_2023-03-04_1d.csv
# │       ├── AAVEUSDT_2023-03-05_1d.csv
# │       ├── AAVEUSDT_2023-03-06_1d.csv
# │       ├── AAVEUSDT_2023-03-07_1d.csv
# │       ├── AAVEUSDT_2023-03-08_1d.csv
# │       ├── AAVEUSDT_2023-03-09_1d.csv
# │       ├── AAVEUSDT_2023-03-10_1d.csv
# │       ├── AAVEUSDT_2023-03-11_1d.csv
# │       ├── AAVEUSDT_2023-03-12_1d.csv
# │       ├── AAVEUSDT_2023-03-13_1d.csv
# │       ├── AAVEUSDT_2023-03-14_1d.csv
# │       ├── AAVEUSDT_2023-03-15_1d.csv
# │       ├── AAVEUSDT_2023-03-16_1d.csv
# │       ├── AAVEUSDT_2023-03-17_1d.csv
# │       ├── AAVEUSDT_2023-03-18_1d.csv
# │       ├── AAVEUSDT_2023-03-19_1d.csv
# │       ├── AAVEUSDT_2023-03-20_1d.csv
# │       ├── AAVEUSDT_2023-03-21_1d.csv
# │       ├── AAVEUSDT_2023-03-22_1d.csv
# │       ├── AAVEUSDT_2023-03-23_1d.csv
# │       ├── AAVEUSDT_2023-03-24_1d.csv
# │       ├── AAVEUSDT_2023-03-25_1d.csv
# │       ├── AAVEUSDT_2023-03-26_1d.csv
# │       ├── AAVEUSDT_2023-03-27_1d.csv
# │       ├── AAVEUSDT_2023-03-28_1d.csv
# │       ├── AAVEUSDT_2023-03-29_1d.csv
# │       ├── AAVEUSDT_2023-03-30_1d.csv
# │       ├── AAVEUSDT_2023-03-31_1d.csv
# │       ├── AAVEUSDT_2023-04-01_1d.csv
# │       ├── AAVEUSDT_2023-04-02_1d.csv
# │       ├── AAVEUSDT_2023-04-03_1d.csv
# │       ├── AAVEUSDT_2023-04-04_1d.csv
# │       ├── AAVEUSDT_2023-04-05_1d.csv
# │       ├── AAVEUSDT_2023-04-06_1d.csv
# │       ├── AAVEUSDT_2023-04-07_1d.csv
# │       ├── AAVEUSDT_2023-04-08_1d.csv
# │       ├── AAVEUSDT_2023-04-09_1d.csv
# │       ├── AAVEUSDT_2023-04-10_1d.csv
# │       ├── AAVEUSDT_2023-04-11_1d.csv
# │       ├── AAVEUSDT_2023-04-12_1d.csv
# │       ├── AAVEUSDT_2023-04-13_1d.csv
# │       ├── AAVEUSDT_2023-04-14_1d.csv
# │       ├── AAVEUSDT_2023-04-15_1d.csv
# │       ├── AAVEUSDT_2023-04-16_1d.csv
# │       ├── AAVEUSDT_2023-04-17_1d.csv
# │       ├── AAVEUSDT_2023-04-18_1d.csv
# │       ├── AAVEUSDT_2023-04-19_1d.csv
# │       ├── AAVEUSDT_2023-04-20_1d.csv
# │       ├── AAVEUSDT_2023-04-21_1d.csv
# │       ├── AAVEUSDT_2023-04-22_1d.csv
# │       ├── AAVEUSDT_2023-04-23_1d.csv
# │       ├── AAVEUSDT_2023-04-24_1d.csv
# │       ├── AAVEUSDT_2023-04-25_1d.csv
# │       ├── AAVEUSDT_2023-04-26_1d.csv
# │       ├── AAVEUSDT_2023-04-27_1d.csv
# │       ├── AAVEUSDT_2023-04-28_1d.csv
# │       ├── AAVEUSDT_2023-04-29_1d.csv
# │       ├── AAVEUSDT_2023-04-30_1d.csv
# │       ├── AAVEUSDT_2023-05-01_1d.csv
# │       ├── AAVEUSDT_2023-05-02_1d.csv
# │       ├── AAVEUSDT_2023-05-03_1d.csv
# │       ├── AAVEUSDT_2023-05-04_1d.csv
# │       ├── AAVEUSDT_2023-05-05_1d.csv
# │       ├── AAVEUSDT_2023-05-06_1d.csv
# │       ├── AAVEUSDT_2023-05-07_1d.csv
# │       ├── AAVEUSDT_2023-05-08_1d.csv
# │       ├── AAVEUSDT_2023-05-09_1d.csv
# │       ├── AAVEUSDT_2023-05-10_1d.csv
# │       ├── AAVEUSDT_2023-05-11_1d.csv
# │       ├── AAVEUSDT_2023-05-12_1d.csv
# │       ├── AAVEUSDT_2023-05-13_1d.csv
# │       ├── AAVEUSDT_2023-05-14_1d.csv
# │       ├── AAVEUSDT_2023-05-15_1d.csv
# │       ├── AAVEUSDT_2023-05-16_1d.csv
# │       ├── AAVEUSDT_2023-05-17_1d.csv
# │       ├── AAVEUSDT_2023-05-18_1d.csv
# │       ├── AAVEUSDT_2023-05-19_1d.csv
# │       ├── AAVEUSDT_2023-05-20_1d.csv
# │       ├── AAVEUSDT_2023-05-21_1d.csv
# │       ├── AAVEUSDT_2023-05-22_1d.csv
# │       ├── AAVEUSDT_2023-05-23_1d.csv
# │       ├── AAVEUSDT_2023-05-24_1d.csv
# │       ├── AAVEUSDT_2023-05-25_1d.csv
# │       ├── AAVEUSDT_2023-05-26_1d.csv
# │       ├── AAVEUSDT_2023-05-27_1d.csv
# │       ├── AAVEUSDT_2023-05-28_1d.csv
# │       ├── AAVEUSDT_2023-05-29_1d.csv
# │       ├── AAVEUSDT_2023-05-30_1d.csv
# │       ├── AAVEUSDT_2023-05-31_1d.csv
# │       ├── AAVEUSDT_2023-06-01_1d.csv
# │       ├── AAVEUSDT_2023-06-02_1d.csv
# │       ├── AAVEUSDT_2023-06-03_1d.csv
# │       ├── AAVEUSDT_2023-06-04_1d.csv
# │       ├── AAVEUSDT_2023-06-05_1d.csv
# │       ├── AAVEUSDT_2023-06-06_1d.csv
# │       ├── AAVEUSDT_2023-06-07_1d.csv
# │       ├── AAVEUSDT_2023-06-08_1d.csv
# │       ├── AAVEUSDT_2023-06-09_1d.csv
# │       ├── AAVEUSDT_2023-06-10_1d.csv
# │       ├── AAVEUSDT_2023-06-11_1d.csv
# │       ├── AAVEUSDT_2023-06-12_1d.csv
# │       ├── AAVEUSDT_2023-06-13_1d.csv
# │       ├── AAVEUSDT_2023-06-14_1d.csv
# │       ├── AAVEUSDT_2023-06-15_1d.csv
# │       ├── AAVEUSDT_2023-06-16_1d.csv
# │       ├── AAVEUSDT_2023-06-17_1d.csv
# │       ├── AAVEUSDT_2023-06-18_1d.csv
# │       ├── AAVEUSDT_2023-06-19_1d.csv
# │       ├── AAVEUSDT_2023-06-20_1d.csv
# │       ├── AAVEUSDT_2023-06-21_1d.csv
# │       ├── AAVEUSDT_2023-06-22_1d.csv
# │       ├── AAVEUSDT_2023-06-23_1d.csv
# │       ├── AAVEUSDT_2023-06-24_1d.csv
# │       ├── AAVEUSDT_2023-06-25_1d.csv
# │       ├── AAVEUSDT_2023-06-26_1d.csv
# │       ├── AAVEUSDT_2023-06-27_1d.csv
# │       ├── AAVEUSDT_2023-06-28_1d.csv
# │       ├── AAVEUSDT_2023-06-29_1d.csv
# │       ├── AAVEUSDT_2023-06-30_1d.csv
# │       ├── AAVEUSDT_2023-07-01_1d.csv
# │       ├── AAVEUSDT_2023-07-02_1d.csv
# │       ├── AAVEUSDT_2023-07-03_1d.csv
# │       ├── AAVEUSDT_2023-07-04_1d.csv
# │       ├── AAVEUSDT_2023-07-05_1d.csv
# │       ├── AAVEUSDT_2023-07-06_1d.csv
# │       ├── AAVEUSDT_2023-07-07_1d.csv
# │       ├── AAVEUSDT_2023-07-08_1d.csv
# │       ├── AAVEUSDT_2023-07-09_1d.csv
# │       ├── AAVEUSDT_2023-07-10_1d.csv
# │       ├── AAVEUSDT_2023-07-11_1d.csv
# │       ├── AAVEUSDT_2023-07-12_1d.csv
# │       ├── AAVEUSDT_2023-07-13_1d.csv
# │       ├── AAVEUSDT_2023-07-14_1d.csv
# │       ├── AAVEUSDT_2023-07-15_1d.csv
# │       ├── AAVEUSDT_2023-07-16_1d.csv
# │       ├── AAVEUSDT_2023-07-17_1d.csv
# │       ├── AAVEUSDT_2023-07-18_1d.csv
# │       ├── AAVEUSDT_2023-07-19_1d.csv
# │       ├── AAVEUSDT_2023-07-20_1d.csv
# │       ├── AAVEUSDT_2023-07-21_1d.csv
# │       ├── AAVEUSDT_2023-07-22_1d.csv
# │       ├── AAVEUSDT_2023-07-23_1d.csv
# │       ├── AAVEUSDT_2023-07-24_1d.csv
# │       ├── AAVEUSDT_2023-07-25_1d.csv
# │       ├── AAVEUSDT_2023-07-26_1d.csv
# │       ├── AAVEUSDT_2023-07-27_1d.csv
# │       ├── AAVEUSDT_2023-07-28_1d.csv
# │       ├── AAVEUSDT_2023-07-29_1d.csv
# │       ├── AAVEUSDT_2023-07-30_1d.csv
# │       ├── AAVEUSDT_2023-07-31_1d.csv
# │       ├── AAVEUSDT_2023-08-01_1d.csv
# │       ├── AAVEUSDT_2023-08-02_1d.csv
# │       ├── AAVEUSDT_2023-08-03_1d.csv
# │       ├── AAVEUSDT_2023-08-04_1d.csv
# │       ├── AAVEUSDT_2023-08-05_1d.csv
# │       ├── AAVEUSDT_2023-08-06_1d.csv
# │       ├── AAVEUSDT_2023-08-07_1d.csv
# │       ├── AAVEUSDT_2023-08-08_1d.csv
# │       ├── AAVEUSDT_2023-08-09_1d.csv
# │       ├── AAVEUSDT_2023-08-10_1d.csv
# │       ├── AAVEUSDT_2023-08-11_1d.csv
# │       ├── AAVEUSDT_2023-08-12_1d.csv
# │       ├── AAVEUSDT_2023-08-13_1d.csv
# │       ├── AAVEUSDT_2023-08-14_1d.csv
# │       ├── AAVEUSDT_2023-08-15_1d.csv
# │       ├── AAVEUSDT_2023-08-16_1d.csv
# │       ├── AAVEUSDT_2023-08-17_1d.csv
# │       ├── AAVEUSDT_2023-08-18_1d.csv
# │       ├── AAVEUSDT_2023-08-19_1d.csv
# │       ├── AAVEUSDT_2023-08-20_1d.csv
# │       ├── AAVEUSDT_2023-08-21_1d.csv
# │       ├── AAVEUSDT_2023-08-22_1d.csv
# │       ├── AAVEUSDT_2023-08-23_1d.csv
# │       ├── AAVEUSDT_2023-08-24_1d.csv
# │       ├── AAVEUSDT_2023-08-25_1d.csv
# │       ├── AAVEUSDT_2023-08-26_1d.csv
# │       ├── AAVEUSDT_2023-08-27_1d.csv
# │       ├── AAVEUSDT_2023-08-28_1d.csv
# │       ├── AAVEUSDT_2023-08-29_1d.csv
# │       ├── AAVEUSDT_2023-08-30_1d.csv
# │       ├── AAVEUSDT_2023-08-31_1d.csv
# │       ├── AAVEUSDT_2023-09-01_1d.csv
# │       ├── AAVEUSDT_2023-09-02_1d.csv
# │       ├── AAVEUSDT_2023-09-03_1d.csv
# │       ├── AAVEUSDT_2023-09-04_1d.csv
# │       ├── AAVEUSDT_2023-09-05_1d.csv
# │       ├── AAVEUSDT_2023-09-06_1d.csv
# │       ├── AAVEUSDT_2023-09-07_1d.csv
# │       ├── AAVEUSDT_2023-09-08_1d.csv
# │       ├── AAVEUSDT_2023-09-09_1d.csv
# │       ├── AAVEUSDT_2023-09-10_1d.csv
# │       ├── AAVEUSDT_2023-09-11_1d.csv
# │       ├── AAVEUSDT_2023-09-12_1d.csv
# │       ├── AAVEUSDT_2023-09-13_1d.csv
# │       ├── AAVEUSDT_2023-09-14_1d.csv
# │       ├── AAVEUSDT_2023-09-15_1d.csv
# │       ├── AAVEUSDT_2023-09-16_1d.csv
# │       ├── AAVEUSDT_2023-09-17_1d.csv
# │       ├── AAVEUSDT_2023-09-18_1d.csv
# │       ├── AAVEUSDT_2023-09-19_1d.csv
# │       ├── AAVEUSDT_2023-09-20_1d.csv
# │       ├── AAVEUSDT_2023-09-21_1d.csv
# │       ├── AAVEUSDT_2023-09-22_1d.csv
# │       ├── AAVEUSDT_2023-09-23_1d.csv
# │       ├── AAVEUSDT_2023-09-24_1d.csv
# │       ├── AAVEUSDT_2023-09-25_1d.csv
# │       ├── AAVEUSDT_2023-09-26_1d.csv
# │       ├── AAVEUSDT_2023-09-27_1d.csv
# │       ├── AAVEUSDT_2023-09-28_1d.csv
# │       ├── AAVEUSDT_2023-09-29_1d.csv
# │       ├── AAVEUSDT_2023-09-30_1d.csv
# │       ├── AAVEUSDT_2023-10-01_1d.csv
# │       ├── AAVEUSDT_2023-10-02_1d.csv
# │       ├── AAVEUSDT_2023-10-03_1d.csv
# │       ├── AAVEUSDT_2023-10-04_1d.csv
# │       ├── AAVEUSDT_2023-10-05_1d.csv
# │       ├── AAVEUSDT_2023-10-06_1d.csv
# │       ├── AAVEUSDT_2023-10-07_1d.csv
# │       ├── AAVEUSDT_2023-10-08_1d.csv
# │       ├── AAVEUSDT_2023-10-09_1d.csv
# │       ├── AAVEUSDT_2023-10-10_1d.csv
# │       ├── AAVEUSDT_2023-10-11_1d.csv
# │       ├── AAVEUSDT_2023-10-12_1d.csv
# │       ├── AAVEUSDT_2023-10-13_1d.csv
# │       ├── AAVEUSDT_2023-10-14_1d.csv
# │       ├── AAVEUSDT_2023-10-15_1d.csv
# │       ├── AAVEUSDT_2023-10-16_1d.csv
# │       ├── AAVEUSDT_2023-10-17_1d.csv
# │       ├── AAVEUSDT_2023-10-18_1d.csv
# │       ├── AAVEUSDT_2023-10-19_1d.csv
# │       ├── AAVEUSDT_2023-10-20_1d.csv
# │       ├── AAVEUSDT_2023-10-21_1d.csv
# │       ├── AAVEUSDT_2023-10-22_1d.csv
# │       ├── AAVEUSDT_2023-10-23_1d.csv
# │       ├── AAVEUSDT_2023-10-24_1d.csv
# │       ├── AAVEUSDT_2023-10-25_1d.csv
# │       ├── AAVEUSDT_2023-10-26_1d.csv
# │       ├── AAVEUSDT_2023-10-27_1d.csv
# │       ├── AAVEUSDT_2023-10-28_1d.csv
# │       ├── AAVEUSDT_2023-10-29_1d.csv
# │       ├── AAVEUSDT_2023-10-30_1d.csv
# │       ├── AAVEUSDT_2023-10-31_1d.csv
# │       ├── AAVEUSDT_2023-11-01_1d.csv
# │       ├── AAVEUSDT_2023-11-02_1d.csv
# │       ├── AAVEUSDT_2023-11-03_1d.csv
# │       ├── AAVEUSDT_2023-11-04_1d.csv
# │       ├── AAVEUSDT_2023-11-05_1d.csv
# │       ├── AAVEUSDT_2023-11-06_1d.csv
# │       ├── AAVEUSDT_2023-11-07_1d.csv
# │       ├── AAVEUSDT_2023-11-08_1d.csv
# │       ├── AAVEUSDT_2023-11-09_1d.csv
# │       ├── AAVEUSDT_2023-11-10_1d.csv
# │       ├── AAVEUSDT_2023-11-11_1d.csv
# │       ├── AAVEUSDT_2023-11-12_1d.csv
# │       ├── AAVEUSDT_2023-11-13_1d.csv
# │       ├── AAVEUSDT_2023-11-14_1d.csv
# │       ├── AAVEUSDT_2023-11-15_1d.csv
# │       ├── AAVEUSDT_2023-11-16_1d.csv
# │       ├── AAVEUSDT_2023-11-17_1d.csv
# │       ├── AAVEUSDT_2023-11-18_1d.csv
# │       ├── AAVEUSDT_2023-11-19_1d.csv
# │       ├── AAVEUSDT_2023-11-20_1d.csv
# │       ├── AAVEUSDT_2023-11-21_1d.csv
# │       ├── AAVEUSDT_2023-11-22_1d.csv
# │       ├── AAVEUSDT_2023-11-23_1d.csv
# │       ├── AAVEUSDT_2023-11-24_1d.csv
# │       ├── AAVEUSDT_2023-11-25_1d.csv
# │       ├── AAVEUSDT_2023-11-26_1d.csv
# │       ├── AAVEUSDT_2023-11-27_1d.csv
# │       ├── AAVEUSDT_2023-11-28_1d.csv
# │       ├── AAVEUSDT_2023-11-29_1d.csv
# │       ├── AAVEUSDT_2023-11-30_1d.csv
# │       ├── AAVEUSDT_2023-12-01_1d.csv
# │       ├── AAVEUSDT_2023-12-02_1d.csv
# │       ├── AAVEUSDT_2023-12-03_1d.csv
# │       ├── AAVEUSDT_2023-12-04_1d.csv
# │       ├── AAVEUSDT_2023-12-05_1d.csv
# │       ├── AAVEUSDT_2023-12-06_1d.csv
# │       ├── AAVEUSDT_2023-12-07_1d.csv
# │       ├── AAVEUSDT_2023-12-08_1d.csv
# │       ├── AAVEUSDT_2023-12-09_1d.csv
# │       ├── AAVEUSDT_2023-12-10_1d.csv
# │       ├── AAVEUSDT_2023-12-11_1d.csv
# │       ├── AAVEUSDT_2023-12-12_1d.csv
# │       ├── AAVEUSDT_2023-12-13_1d.csv
# │       ├── AAVEUSDT_2023-12-14_1d.csv
# │       ├── AAVEUSDT_2023-12-15_1d.csv
# │       ├── AAVEUSDT_2023-12-16_1d.csv
# │       ├── AAVEUSDT_2023-12-17_1d.csv
# │       ├── AAVEUSDT_2023-12-18_1d.csv
# │       ├── AAVEUSDT_2023-12-19_1d.csv
# │       ├── AAVEUSDT_2023-12-20_1d.csv
# │       ├── AAVEUSDT_2023-12-21_1d.csv
# │       ├── AAVEUSDT_2023-12-22_1d.csv
# │       ├── AAVEUSDT_2023-12-23_1d.csv
# │       ├── AAVEUSDT_2023-12-24_1d.csv
# │       ├── AAVEUSDT_2023-12-25_1d.csv
# │       ├── AAVEUSDT_2023-12-26_1d.csv
# │       ├── AAVEUSDT_2023-12-27_1d.csv
# │       ├── AAVEUSDT_2023-12-28_1d.csv
# │       ├── AAVEUSDT_2023-12-29_1d.csv
# │       ├── AAVEUSDT_2023-12-30_1d.csv
# │       ├── AAVEUSDT_2023-12-31_1d.csv
# │       ├── AAVEUSDT_2024-01-01_1d.csv
# │       ├── AAVEUSDT_2024-01-02_1d.csv
# │       ├── AAVEUSDT_2024-01-03_1d.csv
# │       ├── AAVEUSDT_2024-01-04_1d.csv
# │       ├── AAVEUSDT_2024-01-05_1d.csv
# │       ├── AAVEUSDT_2024-01-06_1d.csv
# │       ├── AAVEUSDT_2024-01-07_1d.csv
# │       ├── AAVEUSDT_2024-01-08_1d.csv
# │       ├── AAVEUSDT_2024-01-09_1d.csv
# │       ├── AAVEUSDT_2024-01-10_1d.csv
# │       ├── AAVEUSDT_2024-01-11_1d.csv
# │       ├── AAVEUSDT_2024-01-12_1d.csv
# │       ├── AAVEUSDT_2024-01-13_1d.csv
# │       ├── AAVEUSDT_2024-01-14_1d.csv
# │       ├── AAVEUSDT_2024-01-15_1d.csv
# │       ├── AAVEUSDT_2024-01-16_1d.csv
# │       ├── AAVEUSDT_2024-01-17_1d.csv
# │       ├── AAVEUSDT_2024-01-18_1d.csv
# │       ├── AAVEUSDT_2024-01-19_1d.csv
# │       ├── AAVEUSDT_2024-01-20_1d.csv
# │       ├── AAVEUSDT_2024-01-21_1d.csv
# │       ├── AAVEUSDT_2024-01-22_1d.csv
# │       ├── AAVEUSDT_2024-01-23_1d.csv
# │       ├── AAVEUSDT_2024-01-24_1d.csv
# │       ├── AAVEUSDT_2024-01-25_1d.csv
# │       ├── AAVEUSDT_2024-01-26_1d.csv
# │       ├── AAVEUSDT_2024-01-27_1d.csv
# │       ├── AAVEUSDT_2024-01-28_1d.csv
# │       ├── AAVEUSDT_2024-01-29_1d.csv
# │       ├── AAVEUSDT_2024-01-30_1d.csv
# │       ├── AAVEUSDT_2024-01-31_1d.csv
# │       ├── AAVEUSDT_2024-02-01_1d.csv
# │       ├── AAVEUSDT_2024-02-02_1d.csv
# │       ├── AAVEUSDT_2024-02-03_1d.csv
# │       ├── AAVEUSDT_2024-02-04_1d.csv
# │       ├── AAVEUSDT_2024-02-05_1d.csv
# │       ├── AAVEUSDT_2024-02-06_1d.csv
# │       ├── AAVEUSDT_2024-02-07_1d.csv
# │       ├── AAVEUSDT_2024-02-08_1d.csv
# │       ├── AAVEUSDT_2024-02-09_1d.csv
# │       ├── AAVEUSDT_2024-02-10_1d.csv
# │       ├── AAVEUSDT_2024-02-11_1d.csv
# │       ├── AAVEUSDT_2024-02-12_1d.csv
# │       ├── AAVEUSDT_2024-02-13_1d.csv
# │       ├── AAVEUSDT_2024-02-14_1d.csv
# │       ├── AAVEUSDT_2024-02-15_1d.csv
# │       ├── AAVEUSDT_2024-02-16_1d.csv
# │       ├── AAVEUSDT_2024-02-17_1d.csv
# │       ├── AAVEUSDT_2024-02-18_1d.csv
# │       ├── AAVEUSDT_2024-02-19_1d.csv
# │       ├── AAVEUSDT_2024-02-20_1d.csv
# │       ├── AAVEUSDT_2024-02-21_1d.csv
# │       ├── AAVEUSDT_2024-02-22_1d.csv
# │       ├── AAVEUSDT_2024-02-23_1d.csv
# │       ├── AAVEUSDT_2024-02-24_1d.csv
# │       ├── AAVEUSDT_2024-02-25_1d.csv
# │       ├── AAVEUSDT_2024-02-26_1d.csv
# │       ├── AAVEUSDT_2024-02-27_1d.csv
# │       ├── AAVEUSDT_2024-02-28_1d.csv
# │       ├── AAVEUSDT_2024-02-29_1d.csv
# │       ├── AAVEUSDT_2024-03-01_1d.csv
# │       ├── AAVEUSDT_2024-03-02_1d.csv
# │       ├── AAVEUSDT_2024-03-03_1d.csv
# │       ├── AAVEUSDT_2024-03-04_1d.csv
# │       ├── AAVEUSDT_2024-03-05_1d.csv
# │       ├── AAVEUSDT_2024-03-06_1d.csv
# │       ├── AAVEUSDT_2024-03-07_1d.csv
# │       ├── AAVEUSDT_2024-03-08_1d.csv
# │       ├── AAVEUSDT_2024-03-09_1d.csv
# │       ├── AAVEUSDT_2024-03-10_1d.csv
# │       ├── AAVEUSDT_2024-03-11_1d.csv
# │       ├── AAVEUSDT_2024-03-12_1d.csv
# │       ├── AAVEUSDT_2024-03-13_1d.csv
# │       ├── AAVEUSDT_2024-03-14_1d.csv
# │       ├── AAVEUSDT_2024-03-15_1d.csv
# │       ├── AAVEUSDT_2024-03-16_1d.csv
# │       ├── AAVEUSDT_2024-03-17_1d.csv
# │       ├── AAVEUSDT_2024-03-18_1d.csv
# │       ├── AAVEUSDT_2024-03-19_1d.csv
# │       ├── AAVEUSDT_2024-03-20_1d.csv
# │       ├── AAVEUSDT_2024-03-21_1d.csv
# │       ├── AAVEUSDT_2024-03-22_1d.csv
# │       ├── AAVEUSDT_2024-03-23_1d.csv
# │       ├── AAVEUSDT_2024-03-24_1d.csv
# │       ├── AAVEUSDT_2024-03-25_1d.csv
# │       ├── AAVEUSDT_2024-03-26_1d.csv
# │       ├── AAVEUSDT_2024-03-27_1d.csv
# │       ├── AAVEUSDT_2024-03-28_1d.csv
# │       ├── AAVEUSDT_2024-03-29_1d.csv
# │       ├── AAVEUSDT_2024-03-30_1d.csv
# │       ├── AAVEUSDT_2024-03-31_1d.csv
# │       ├── AAVEUSDT_2024-04-01_1d.csv
# │       ├── AAVEUSDT_2024-04-02_1d.csv
# │       ├── AAVEUSDT_2024-04-03_1d.csv
# │       ├── AAVEUSDT_2024-04-04_1d.csv
# │       ├── AAVEUSDT_2024-04-05_1d.csv
# │       ├── AAVEUSDT_2024-04-06_1d.csv
# │       ├── AAVEUSDT_2024-04-07_1d.csv
# │       ├── AAVEUSDT_2024-04-08_1d.csv
# │       ├── AAVEUSDT_2024-04-09_1d.csv
# │       ├── AAVEUSDT_2024-04-10_1d.csv
# │       ├── AAVEUSDT_2024-04-11_1d.csv
# │       ├── AAVEUSDT_2024-04-12_1d.csv
# │       ├── AAVEUSDT_2024-04-13_1d.csv
# │       ├── AAVEUSDT_2024-04-14_1d.csv
# │       ├── AAVEUSDT_2024-04-15_1d.csv
# │       ├── AAVEUSDT_2024-04-16_1d.csv
# │       ├── AAVEUSDT_2024-04-17_1d.csv
# │       ├── AAVEUSDT_2024-04-18_1d.csv
# │       ├── AAVEUSDT_2024-04-19_1d.csv
# │       ├── AAVEUSDT_2024-04-20_1d.csv
# │       ├── AAVEUSDT_2024-04-21_1d.csv
# │       ├── AAVEUSDT_2024-04-22_1d.csv
# │       ├── AAVEUSDT_2024-04-23_1d.csv
# │       ├── AAVEUSDT_2024-04-24_1d.csv
# │       ├── AAVEUSDT_2024-04-25_1d.csv
# │       ├── AAVEUSDT_2024-04-26_1d.csv
# │       ├── AAVEUSDT_2024-04-27_1d.csv
# │       ├── AAVEUSDT_2024-04-28_1d.csv
# │       ├── AAVEUSDT_2024-04-29_1d.csv
# │       ├── AAVEUSDT_2024-04-30_1d.csv
# │       ├── AAVEUSDT_2024-05-01_1d.csv
# │       ├── AAVEUSDT_2024-05-02_1d.csv
# │       ├── AAVEUSDT_2024-05-03_1d.csv
# │       ├── AAVEUSDT_2024-05-04_1d.csv
# │       ├── AAVEUSDT_2024-05-05_1d.csv
# │       ├── AAVEUSDT_2024-05-06_1d.csv
# │       ├── AAVEUSDT_2024-05-07_1d.csv
# │       ├── AAVEUSDT_2024-05-08_1d.csv
# │       ├── AAVEUSDT_2024-05-09_1d.csv
# │       ├── AAVEUSDT_2024-05-10_1d.csv
# │       ├── AAVEUSDT_2024-05-11_1d.csv
# ...
#         ├── XTZUSDT_2024-03-25_1d.csv
#         ├── XTZUSDT_2024-03-26_1d.csv
#         ├── XTZUSDT_2024-03-27_1d.csv
#         ├── XTZUSDT_2024-03-28_1d.csv
#         ├── XTZUSDT_2024-03-29_1d.csv
#         ├── XTZUSDT_2024-03-30_1d.csv
#         ├── XTZUSDT_2024-03-31_1d.csv
#         ├── XTZUSDT_2024-04-01_1d.csv
#         ├── XTZUSDT_2024-04-02_1d.csv
#         ├── XTZUSDT_2024-04-03_1d.csv
#         ├── XTZUSDT_2024-04-04_1d.csv
#         ├── XTZUSDT_2024-04-05_1d.csv
#         ├── XTZUSDT_2024-04-06_1d.csv
#         ├── XTZUSDT_2024-04-07_1d.csv
#         ├── XTZUSDT_2024-04-08_1d.csv
#         ├── XTZUSDT_2024-04-09_1d.csv
#         ├── XTZUSDT_2024-04-10_1d.csv
#         ├── XTZUSDT_2024-04-11_1d.csv
#         ├── XTZUSDT_2024-04-12_1d.csv
#         ├── XTZUSDT_2024-04-13_1d.csv
#         ├── XTZUSDT_2024-04-14_1d.csv
#         ├── XTZUSDT_2024-04-15_1d.csv
#         ├── XTZUSDT_2024-04-16_1d.csv
#         ├── XTZUSDT_2024-04-17_1d.csv
#         ├── XTZUSDT_2024-04-18_1d.csv
#         ├── XTZUSDT_2024-04-19_1d.csv
#         ├── XTZUSDT_2024-04-20_1d.csv
#         ├── XTZUSDT_2024-04-21_1d.csv
#         ├── XTZUSDT_2024-04-22_1d.csv
#         ├── XTZUSDT_2024-04-23_1d.csv
#         ├── XTZUSDT_2024-04-24_1d.csv
#         ├── XTZUSDT_2024-04-25_1d.csv
#         ├── XTZUSDT_2024-04-26_1d.csv
#         ├── XTZUSDT_2024-04-27_1d.csv
#         ├── XTZUSDT_2024-04-28_1d.csv
#         ├── XTZUSDT_2024-04-29_1d.csv
#         ├── XTZUSDT_2024-04-30_1d.csv
#         ├── XTZUSDT_2024-05-01_1d.csv
#         ├── XTZUSDT_2024-05-02_1d.csv
#         ├── XTZUSDT_2024-05-03_1d.csv
#         ├── XTZUSDT_2024-05-04_1d.csv
#         ├── XTZUSDT_2024-05-05_1d.csv
#         ├── XTZUSDT_2024-05-06_1d.csv
#         ├── XTZUSDT_2024-05-07_1d.csv
#         ├── XTZUSDT_2024-05-08_1d.csv
#         ├── XTZUSDT_2024-05-09_1d.csv
#         ├── XTZUSDT_2024-05-10_1d.csv
#         ├── XTZUSDT_2024-05-11_1d.csv
#         ├── XTZUSDT_2024-05-12_1d.csv
#         ├── XTZUSDT_2024-05-13_1d.csv
#         ├── XTZUSDT_2024-05-14_1d.csv
#         ├── XTZUSDT_2024-05-15_1d.csv
#         ├── XTZUSDT_2024-05-16_1d.csv
#         ├── XTZUSDT_2024-05-17_1d.csv
#         ├── XTZUSDT_2024-05-18_1d.csv
#         ├── XTZUSDT_2024-05-19_1d.csv
#         ├── XTZUSDT_2024-05-20_1d.csv
#         ├── XTZUSDT_2024-05-21_1d.csv
#         ├── XTZUSDT_2024-05-22_1d.csv
#         ├── XTZUSDT_2024-05-23_1d.csv
#         ├── XTZUSDT_2024-05-24_1d.csv
#         ├── XTZUSDT_2024-05-25_1d.csv
#         ├── XTZUSDT_2024-05-26_1d.csv
#         ├── XTZUSDT_2024-05-27_1d.csv
#         ├── XTZUSDT_2024-05-28_1d.csv
#         ├── XTZUSDT_2024-05-29_1d.csv
#         ├── XTZUSDT_2024-05-30_1d.csv
#         ├── XTZUSDT_2024-05-31_1d.csv
#         ├── XTZUSDT_2024-06-01_1d.csv
#         ├── XTZUSDT_2024-06-02_1d.csv
#         ├── XTZUSDT_2024-06-03_1d.csv
#         ├── XTZUSDT_2024-06-04_1d.csv
#         ├── XTZUSDT_2024-06-05_1d.csv
#         ├── XTZUSDT_2024-06-06_1d.csv
#         ├── XTZUSDT_2024-06-07_1d.csv
#         ├── XTZUSDT_2024-06-08_1d.csv
#         ├── XTZUSDT_2024-06-09_1d.csv
#         ├── XTZUSDT_2024-06-10_1d.csv
#         ├── XTZUSDT_2024-06-11_1d.csv
#         ├── XTZUSDT_2024-06-12_1d.csv
#         ├── XTZUSDT_2024-06-13_1d.csv
#         ├── XTZUSDT_2024-06-14_1d.csv
#         ├── XTZUSDT_2024-06-15_1d.csv
#         ├── XTZUSDT_2024-06-16_1d.csv
#         ├── XTZUSDT_2024-06-17_1d.csv
#         ├── XTZUSDT_2024-06-18_1d.csv
#         ├── XTZUSDT_2024-06-19_1d.csv
#         ├── XTZUSDT_2024-06-20_1d.csv
#         ├── XTZUSDT_2024-06-21_1d.csv
#         ├── XTZUSDT_2024-06-22_1d.csv
#         ├── XTZUSDT_2024-06-23_1d.csv
#         ├── XTZUSDT_2024-06-24_1d.csv
#         ├── XTZUSDT_2024-06-25_1d.csv
#         ├── XTZUSDT_2024-06-26_1d.csv
#         ├── XTZUSDT_2024-06-27_1d.csv
#         ├── XTZUSDT_2024-06-28_1d.csv
#         ├── XTZUSDT_2024-06-29_1d.csv
#         ├── XTZUSDT_2024-06-30_1d.csv
#         ├── XTZUSDT_2024-07-01_1d.csv
#         ├── XTZUSDT_2024-07-02_1d.csv
#         ├── XTZUSDT_2024-07-03_1d.csv
#         ├── XTZUSDT_2024-07-04_1d.csv
#         ├── XTZUSDT_2024-07-05_1d.csv
#         ├── XTZUSDT_2024-07-06_1d.csv
#         ├── XTZUSDT_2024-07-07_1d.csv
#         ├── XTZUSDT_2024-07-08_1d.csv
#         ├── XTZUSDT_2024-07-09_1d.csv
#         ├── XTZUSDT_2024-07-10_1d.csv
#         ├── XTZUSDT_2024-07-11_1d.csv
#         ├── XTZUSDT_2024-07-12_1d.csv
#         ├── XTZUSDT_2024-07-13_1d.csv
#         ├── XTZUSDT_2024-07-14_1d.csv
#         ├── XTZUSDT_2024-07-15_1d.csv
#         ├── XTZUSDT_2024-07-16_1d.csv
#         ├── XTZUSDT_2024-07-17_1d.csv
#         ├── XTZUSDT_2024-07-18_1d.csv
#         ├── XTZUSDT_2024-07-19_1d.csv
#         ├── XTZUSDT_2024-07-20_1d.csv
#         ├── XTZUSDT_2024-07-21_1d.csv
#         ├── XTZUSDT_2024-07-22_1d.csv
#         ├── XTZUSDT_2024-07-23_1d.csv
#         ├── XTZUSDT_2024-07-24_1d.csv
#         ├── XTZUSDT_2024-07-25_1d.csv
#         ├── XTZUSDT_2024-07-26_1d.csv
#         ├── XTZUSDT_2024-07-27_1d.csv
#         ├── XTZUSDT_2024-07-28_1d.csv
#         ├── XTZUSDT_2024-07-29_1d.csv
#         ├── XTZUSDT_2024-07-30_1d.csv
#         ├── XTZUSDT_2024-07-31_1d.csv
#         ├── XTZUSDT_2024-08-01_1d.csv
#         ├── XTZUSDT_2024-08-02_1d.csv
#         ├── XTZUSDT_2024-08-03_1d.csv
#         ├── XTZUSDT_2024-08-04_1d.csv
#         ├── XTZUSDT_2024-08-05_1d.csv
#         ├── XTZUSDT_2024-08-06_1d.csv
#         ├── XTZUSDT_2024-08-07_1d.csv
#         ├── XTZUSDT_2024-08-08_1d.csv
#         ├── XTZUSDT_2024-08-09_1d.csv
#         ├── XTZUSDT_2024-08-10_1d.csv
#         ├── XTZUSDT_2024-08-11_1d.csv
#         ├── XTZUSDT_2024-08-12_1d.csv
#         ├── XTZUSDT_2024-08-13_1d.csv
#         ├── XTZUSDT_2024-08-14_1d.csv
#         ├── XTZUSDT_2024-08-15_1d.csv
#         ├── XTZUSDT_2024-08-16_1d.csv
#         ├── XTZUSDT_2024-08-17_1d.csv
#         ├── XTZUSDT_2024-08-18_1d.csv
#         ├── XTZUSDT_2024-08-19_1d.csv
#         ├── XTZUSDT_2024-08-20_1d.csv
#         ├── XTZUSDT_2024-08-21_1d.csv
#         ├── XTZUSDT_2024-08-22_1d.csv
#         ├── XTZUSDT_2024-08-23_1d.csv
#         ├── XTZUSDT_2024-08-24_1d.csv
#         ├── XTZUSDT_2024-08-25_1d.csv
#         ├── XTZUSDT_2024-08-26_1d.csv
#         ├── XTZUSDT_2024-08-27_1d.csv
#         ├── XTZUSDT_2024-08-28_1d.csv
#         ├── XTZUSDT_2024-08-29_1d.csv
#         ├── XTZUSDT_2024-08-30_1d.csv
#         ├── XTZUSDT_2024-08-31_1d.csv
#         ├── XTZUSDT_2024-09-01_1d.csv
#         ├── XTZUSDT_2024-09-02_1d.csv
#         ├── XTZUSDT_2024-09-03_1d.csv
#         ├── XTZUSDT_2024-09-04_1d.csv
#         ├── XTZUSDT_2024-09-05_1d.csv
#         ├── XTZUSDT_2024-09-06_1d.csv
#         ├── XTZUSDT_2024-09-07_1d.csv
#         ├── XTZUSDT_2024-09-08_1d.csv
#         ├── XTZUSDT_2024-09-09_1d.csv
#         ├── XTZUSDT_2024-09-10_1d.csv
#         ├── XTZUSDT_2024-09-11_1d.csv
#         ├── XTZUSDT_2024-09-12_1d.csv
#         ├── XTZUSDT_2024-09-13_1d.csv
#         ├── XTZUSDT_2024-09-14_1d.csv
#         ├── XTZUSDT_2024-09-15_1d.csv
#         ├── XTZUSDT_2024-09-16_1d.csv
#         ├── XTZUSDT_2024-09-17_1d.csv
#         ├── XTZUSDT_2024-09-18_1d.csv
#         ├── XTZUSDT_2024-09-19_1d.csv
#         ├── XTZUSDT_2024-09-20_1d.csv
#         ├── XTZUSDT_2024-09-21_1d.csv
#         ├── XTZUSDT_2024-09-22_1d.csv
#         ├── XTZUSDT_2024-09-23_1d.csv
#         ├── XTZUSDT_2024-09-24_1d.csv
#         ├── XTZUSDT_2024-09-25_1d.csv
#         ├── XTZUSDT_2024-09-26_1d.csv
#         ├── XTZUSDT_2024-09-27_1d.csv
#         ├── XTZUSDT_2024-09-28_1d.csv
#         ├── XTZUSDT_2024-09-29_1d.csv
#         ├── XTZUSDT_2024-09-30_1d.csv
#         ├── XTZUSDT_2024-10-01_1d.csv
#         ├── XTZUSDT_2024-10-02_1d.csv
#         ├── XTZUSDT_2024-10-03_1d.csv
#         ├── XTZUSDT_2024-10-04_1d.csv
#         ├── XTZUSDT_2024-10-05_1d.csv
#         ├── XTZUSDT_2024-10-06_1d.csv
#         ├── XTZUSDT_2024-10-07_1d.csv
#         ├── XTZUSDT_2024-10-08_1d.csv
#         ├── XTZUSDT_2024-10-09_1d.csv
#         ├── XTZUSDT_2024-10-10_1d.csv
#         ├── XTZUSDT_2024-10-11_1d.csv
#         ├── XTZUSDT_2024-10-12_1d.csv
#         ├── XTZUSDT_2024-10-13_1d.csv
#         ├── XTZUSDT_2024-10-14_1d.csv
#         ├── XTZUSDT_2024-10-15_1d.csv
#         ├── XTZUSDT_2024-10-16_1d.csv
#         ├── XTZUSDT_2024-10-17_1d.csv
#         ├── XTZUSDT_2024-10-18_1d.csv
#         ├── XTZUSDT_2024-10-19_1d.csv
#         ├── XTZUSDT_2024-10-20_1d.csv
#         ├── XTZUSDT_2024-10-21_1d.csv
#         ├── XTZUSDT_2024-10-22_1d.csv
#         ├── XTZUSDT_2024-10-23_1d.csv
#         ├── XTZUSDT_2024-10-24_1d.csv
#         ├── XTZUSDT_2024-10-25_1d.csv
#         ├── XTZUSDT_2024-10-26_1d.csv
#         ├── XTZUSDT_2024-10-27_1d.csv
#         ├── XTZUSDT_2024-10-28_1d.csv
#         ├── XTZUSDT_2024-10-29_1d.csv
#         ├── XTZUSDT_2024-10-30_1d.csv
#         ├── XTZUSDT_2024-10-31_1d.csv
#         ├── XTZUSDT_2024-11-01_1d.csv
#         ├── XTZUSDT_2024-11-02_1d.csv
#         ├── XTZUSDT_2024-11-03_1d.csv
#         ├── XTZUSDT_2024-11-04_1d.csv
#         ├── XTZUSDT_2024-11-05_1d.csv
#         ├── XTZUSDT_2024-11-06_1d.csv
#         ├── XTZUSDT_2024-11-07_1d.csv
#         ├── XTZUSDT_2024-11-08_1d.csv
#         ├── XTZUSDT_2024-11-09_1d.csv
#         ├── XTZUSDT_2024-11-10_1d.csv
#         ├── XTZUSDT_2024-11-11_1d.csv
#         ├── XTZUSDT_2024-11-12_1d.csv
#         ├── XTZUSDT_2024-11-13_1d.csv
#         ├── XTZUSDT_2024-11-14_1d.csv
#         ├── XTZUSDT_2024-11-15_1d.csv
#         ├── XTZUSDT_2024-11-16_1d.csv
#         ├── XTZUSDT_2024-11-17_1d.csv
#         ├── XTZUSDT_2024-11-18_1d.csv
#         ├── XTZUSDT_2024-11-19_1d.csv
#         ├── XTZUSDT_2024-11-20_1d.csv
#         ├── XTZUSDT_2024-11-21_1d.csv
#         ├── XTZUSDT_2024-11-22_1d.csv
#         ├── XTZUSDT_2024-11-23_1d.csv
#         ├── XTZUSDT_2024-11-24_1d.csv
#         ├── XTZUSDT_2024-11-25_1d.csv
#         ├── XTZUSDT_2024-11-26_1d.csv
#         ├── XTZUSDT_2024-11-27_1d.csv
#         ├── XTZUSDT_2024-11-28_1d.csv
#         ├── XTZUSDT_2024-11-29_1d.csv
#         ├── XTZUSDT_2024-11-30_1d.csv
#         ├── XTZUSDT_2024-12-01_1d.csv
#         ├── XTZUSDT_2024-12-02_1d.csv
#         ├── XTZUSDT_2024-12-03_1d.csv
#         ├── XTZUSDT_2024-12-04_1d.csv
#         ├── XTZUSDT_2024-12-05_1d.csv
#         ├── XTZUSDT_2024-12-06_1d.csv
#         ├── XTZUSDT_2024-12-07_1d.csv
#         ├── XTZUSDT_2024-12-08_1d.csv
#         ├── XTZUSDT_2024-12-09_1d.csv
#         ├── XTZUSDT_2024-12-10_1d.csv
#         ├── XTZUSDT_2024-12-11_1d.csv
#         ├── XTZUSDT_2024-12-12_1d.csv
#         ├── XTZUSDT_2024-12-13_1d.csv
#         ├── XTZUSDT_2024-12-14_1d.csv
#         ├── XTZUSDT_2024-12-15_1d.csv
#         ├── XTZUSDT_2024-12-16_1d.csv
#         ├── XTZUSDT_2024-12-17_1d.csv
#         ├── XTZUSDT_2024-12-18_1d.csv
#         ├── XTZUSDT_2024-12-19_1d.csv
#         ├── XTZUSDT_2024-12-20_1d.csv
#         ├── XTZUSDT_2024-12-21_1d.csv
#         ├── XTZUSDT_2024-12-22_1d.csv
#         ├── XTZUSDT_2024-12-23_1d.csv
#         ├── XTZUSDT_2024-12-24_1d.csv
#         ├── XTZUSDT_2024-12-25_1d.csv
#         ├── XTZUSDT_2024-12-26_1d.csv
#         ├── XTZUSDT_2024-12-27_1d.csv
#         ├── XTZUSDT_2024-12-28_1d.csv
#         ├── XTZUSDT_2024-12-29_1d.csv
#         ├── XTZUSDT_2024-12-30_1d.csv
#         ├── XTZUSDT_2024-12-31_1d.csv
#         ├── XTZUSDT_2025-01-01_1d.csv
#         ├── XTZUSDT_2025-01-02_1d.csv
#         ├── XTZUSDT_2025-01-03_1d.csv
#         ├── XTZUSDT_2025-01-04_1d.csv
#         ├── XTZUSDT_2025-01-05_1d.csv
#         ├── XTZUSDT_2025-01-06_1d.csv
#         ├── XTZUSDT_2025-01-07_1d.csv
#         ├── XTZUSDT_2025-01-08_1d.csv
#         ├── XTZUSDT_2025-01-09_1d.csv
#         ├── XTZUSDT_2025-01-10_1d.csv
#         ├── XTZUSDT_2025-01-11_1d.csv
#         ├── XTZUSDT_2025-01-12_1d.csv
#         ├── XTZUSDT_2025-01-13_1d.csv
#         ├── XTZUSDT_2025-01-14_1d.csv
#         ├── XTZUSDT_2025-01-15_1d.csv
#         ├── XTZUSDT_2025-01-16_1d.csv
#         ├── XTZUSDT_2025-01-17_1d.csv
#         ├── XTZUSDT_2025-01-18_1d.csv
#         ├── XTZUSDT_2025-01-19_1d.csv
#         ├── XTZUSDT_2025-01-20_1d.csv
#         ├── XTZUSDT_2025-01-21_1d.csv
#         ├── XTZUSDT_2025-01-22_1d.csv
#         ├── XTZUSDT_2025-01-23_1d.csv
#         ├── XTZUSDT_2025-01-24_1d.csv
#         ├── XTZUSDT_2025-01-25_1d.csv
#         ├── XTZUSDT_2025-01-26_1d.csv
#         ├── XTZUSDT_2025-01-27_1d.csv
#         ├── XTZUSDT_2025-01-28_1d.csv
#         ├── XTZUSDT_2025-01-29_1d.csv
#         ├── XTZUSDT_2025-01-30_1d.csv
#         ├── XTZUSDT_2025-01-31_1d.csv
#         ├── XTZUSDT_2025-02-01_1d.csv
#         ├── XTZUSDT_2025-02-02_1d.csv
#         ├── XTZUSDT_2025-02-03_1d.csv
#         ├── XTZUSDT_2025-02-04_1d.csv
#         ├── XTZUSDT_2025-02-05_1d.csv
#         ├── XTZUSDT_2025-02-06_1d.csv
#         ├── XTZUSDT_2025-02-07_1d.csv
#         ├── XTZUSDT_2025-02-08_1d.csv
#         ├── XTZUSDT_2025-02-09_1d.csv
#         ├── XTZUSDT_2025-02-10_1d.csv
#         ├── XTZUSDT_2025-02-11_1d.csv
#         ├── XTZUSDT_2025-02-12_1d.csv
#         ├── XTZUSDT_2025-02-13_1d.csv
#         ├── XTZUSDT_2025-02-14_1d.csv
#         ├── XTZUSDT_2025-02-15_1d.csv
#         ├── XTZUSDT_2025-02-16_1d.csv
#         ├── XTZUSDT_2025-02-17_1d.csv
#         ├── XTZUSDT_2025-02-18_1d.csv
#         ├── XTZUSDT_2025-02-19_1d.csv
#         ├── XTZUSDT_2025-02-20_1d.csv
#         ├── XTZUSDT_2025-02-21_1d.csv
#         ├── XTZUSDT_2025-02-22_1d.csv
#         ├── XTZUSDT_2025-02-23_1d.csv
#         ├── XTZUSDT_2025-02-24_1d.csv
#         ├── XTZUSDT_2025-02-25_1d.csv
#         └── XTZUSDT_2025-02-26_1d.csv
#
# === Loading data in LONG format ===
# Found 21 available symbols with 1d frequency: ['AAVEUSDT', 'ADAUSDT', 'AVAXUSDT', 'BCHUSDT', 'BNBUSDT']...
# Processing 1/21: AAVEUSDT
#   Successfully loaded AAVEUSDT with 1518 rows
# Processing 2/21: ADAUSDT
#   Successfully loaded ADAUSDT with 1518 rows
# Processing 3/21: AVAXUSDT
#   Successfully loaded AVAXUSDT with 1518 rows
# Processing 4/21: BCHUSDT
#   Successfully loaded BCHUSDT with 1518 rows
# Processing 5/21: BNBUSDT
#   Successfully loaded BNBUSDT with 1518 rows
# Processing 6/21: BTCUSDT
#   Successfully loaded BTCUSDT with 1518 rows
# Processing 7/21: DOGEUSDT
#   Successfully loaded DOGEUSDT with 1518 rows
# Processing 8/21: DOTUSDT
#   Successfully loaded DOTUSDT with 1518 rows
# Processing 9/21: ETCUSDT
#   Successfully loaded ETCUSDT with 1518 rows
# Processing 10/21: ETHUSDT
#   Successfully loaded ETHUSDT with 1518 rows
# Processing 11/21: LINKUSDT
#   Successfully loaded LINKUSDT with 1518 rows
# Processing 12/21: LTCUSDT
#   Successfully loaded LTCUSDT with 1518 rows
# Processing 13/21: NEARUSDT
#   Successfully loaded NEARUSDT with 1518 rows
# Processing 14/21: SOLUSDT
#   Successfully loaded SOLUSDT with 1518 rows
# Processing 15/21: THETAUSDT
#   Successfully loaded THETAUSDT with 1518 rows
# Processing 16/21: TRXUSDT
#   Successfully loaded TRXUSDT with 1518 rows
# Processing 17/21: UNIUSDT
#   Successfully loaded UNIUSDT with 1518 rows
# Processing 18/21: VETUSDT
#   Successfully loaded VETUSDT with 1518 rows
# Processing 19/21: XLMUSDT
#   Successfully loaded XLMUSDT with 1518 rows
# Processing 20/21: XRPUSDT
#   Successfully loaded XRPUSDT with 1518 rows
# Processing 21/21: XTZUSDT
#   Successfully loaded XTZUSDT with 1518 rows
#
# Combining all symbols into long format...
# Final long-format dataset has 31878 rows with data for 21 symbols
#
# Data Quality Report:
# Total rows: 31878
# Date range: 2021-01-01 00:00:00 to 2025-02-26 00:00:00
# Total symbols: 21
# Saved data to /Users/mouyasushi/Desktop/quantDevops/Research/Alpha-Research/kline/binance/all_crypto_data_1d_long.parquet
#
# Sample of long-format data:
#    open_time     open     high     low    close     volume  \
# 0 2021-01-01   88.581   91.000  84.652   90.909   368132.6
# 1 2021-01-02   90.940   92.200  82.573   85.888   350675.1
# 2 2021-01-03   85.911   95.680  81.338   94.185   490412.4
# 3 2021-01-04   94.183  115.590  85.932  114.322  1108493.1
# 4 2021-01-05  114.344  124.279  98.653  119.800   843809.1
#
#    quote_asset_volume  number_of_trades  taker_buy_base_asset_volume  \
# 0        3.236081e+07             95220                     160420.1
# 1        3.019238e+07             96482                     141557.9
# 2        4.367915e+07            120659                     219913.4
# 3        1.136470e+08            301713                     514642.8
# 4        9.551636e+07            271640                     385402.1
#
#    taker_buy_quote_asset_volume    symbol
# 0                  1.411901e+07  AAVEUSDT
# 1                  1.219980e+07  AAVEUSDT
# 2                  1.964500e+07  AAVEUSDT
# 3                  5.291774e+07  AAVEUSDT
# 4                  4.365867e+07  AAVEUSDT

# %%
path = '/Users/mouyasushi/Desktop/quantDevops/Research/Alpha-Research/kline/binance/all_crypto_data_1d_long.parquet'

load_parquet_data(path)
# Out:
# Successfully loaded data from /Users/mouyasushi/Desktop/quantDevops/Research/Alpha-Research/kline/binance/all_crypto_data_1d_long.parquet
# Shape: (31878, 11) (rows, columns)
# Format: Long format
# Date range: 2021-01-01 00:00:00 to 2025-02-26 00:00:00
# Contains data for 21 cryptocurrencies
#        open_time     open     high     low    close      volume  \
# 0     2021-01-01   88.581   91.000  84.652   90.909    368132.6
# 1     2021-01-02   90.940   92.200  82.573   85.888    350675.1
# 2     2021-01-03   85.911   95.680  81.338   94.185    490412.4
# 3     2021-01-04   94.183  115.590  85.932  114.322   1108493.1
# 4     2021-01-05  114.344  124.279  98.653  119.800    843809.1
# ...          ...      ...      ...     ...      ...         ...
# 31873 2025-02-22    0.870    0.899   0.867    0.893   9587461.5
# 31874 2025-02-23    0.893    0.895   0.858    0.865   5712478.5
# 31875 2025-02-24    0.865    0.866   0.761    0.773  19900237.0
# 31876 2025-02-25    0.772    0.791   0.725    0.777  28215329.7
# 31877 2025-02-26    0.777    0.789   0.741    0.761  18074143.0
#
#        quote_asset_volume  number_of_trades  taker_buy_base_asset_volume  \
# 0            3.236081e+07             95220                     160420.1
# 1            3.019238e+07             96482                     141557.9
# 2            4.367915e+07            120659                     219913.4
# 3            1.136470e+08            301713                     514642.8
# 4            9.551636e+07            271640                     385402.1
# ...                   ...               ...                          ...
# 31873        8.503384e+06             46368                    4670777.7
# 31874        5.005713e+06             39536                    2578248.6
# 31875        1.618839e+07             91384                    9703884.8
# 31876        2.147710e+07            112628                   14213387.9
# 31877        1.385716e+07             71220                    9173244.8
#
#        taker_buy_quote_asset_volume    symbol
# 0                      1.411901e+07  AAVEUSDT
# 1                      1.219980e+07  AAVEUSDT
# 2                      1.964500e+07  AAVEUSDT
# 3                      5.291774e+07  AAVEUSDT
# 4                      4.365867e+07  AAVEUSDT
# ...                             ...       ...
# 31873                  4.143709e+06   XTZUSDT
# 31874                  2.258186e+06   XTZUSDT
# 31875                  7.900364e+06   XTZUSDT
# 31876                  1.081920e+07   XTZUSDT
# 31877                  7.038722e+06   XTZUSDT
#
# [31878 rows x 11 columns]
